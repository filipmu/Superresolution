# %% [markdown]
# # Apply AI Superresolution to video - Train New Network from Video Frames
#
# ## Use a perception loss
# https://github.com/richzhang/PerceptualSimilarity
#
#
#
# # Get a video dataset to do better training
# - higher resolution than used in research
#
# ### super 8 look https://www.youtube.com/watch?v=7Q5UZmwxIXo
# - low focus (diffusion and blur - bokah)
# - low contrast
# - camera is more shakey on home movies
# - high depth of field everything is sharp
# - 4x3
# - film grain
# - color changes
# - mpeg2 compression noise
#
# ### VCR look
# - jitter on scan lines - see http://www.avisynth.nl/users/vcmohan/DeJitter/DeJitter.htm
# - chroma issues https://forum.videohelp.com/threads/397928-Imrpove-old-video-recorded-by-a-bad-camera?s=0a1230911434e7442d05b6b6cee8e6d2
#
# - jpeg compression artifacts
#
# ## use images of related material to train superres
# - family photos to train for family videos
# - need water and outdoors
# - use video samples for video
# - use film examples for super8
#
# ## Data Augmentation
# - sample a few frames from a few places - complete
# - different blur levels- complete
# - different blur levels in the same image - complete
# - convolution with disk - complete
# - left-right flip - complete
# - contrast and brightness - complete
# - random crop - use center crop
# - crop to the super8 resolution 720x480 or video 320x240 - complete
# - GAN statistics
# - predict level of blur with same network to encourage differentiation to that
# - input of a filter that detects light reflections to help infer blurring
# - try mixup
# - use a single shot classifier output as an input
#
# - see this library for blending images https://pypi.org/project/blend-modes/
#
#
# ## Optimization
# - Use Adam - complete
# - Use optimal learning rate
# - freeze layers
# - dropout
# - use fp16 - pytorch1.6 has a new library for this - complete
# - train on low res and increase resolution - does not seem to help in convergence
#
# ## losses
# - try l1 loss - does not converge
# - try perceptive loss vgg18 - complete
# - perceptive loss uses 256x256 images - too low res, so use overlapping subsets of image to calc loss
# - combine perceptive and mse loss
# - calculate mse loss on a smoothed version of output compared to input (which is smoothed) - ensure reversal matches
#
#
# ## do comparisons for standard test sets
# - not super useful since they use gaussian blurring, bicubic interpolation
# - get very focused images and use as a validation and test set - prefer one thats published
#
#
# ## Results & Analysis
# - Fixes - jpeg artifacts were fixed at one level 30 and slope at 0.01 in:
# Superresolution train vdsr with multifuz
# Superresolution train vdsr with perception loss multifuz
#
# - mse only goes so far.  too strict
# - Perceptual loss helps improve it, but input is 256x256 resolution so limited sharpness.
# - Perceptual loss tiled (hires) causes too much causes artifacts
# - multifuz improves results especially with perceptual loss, handles different fuzziness better
#
# Next experiment
# - training may not need to go as long - complete
# - set kernel range from 1 to 20 - vs 4-20 need lower range too - complete
# - combination of hi res perceptual and mse on smoothed versions of input.- complete
# - give more emphasis to mse
#
# Other ideas
# - train on cleaner images div8K
# - cascade 2 models.  Train first as usual.  Use it to preprocess input to train second model
# - apply mix-up
# - better model and apply to all 3 colors - tried, but no improvement.
# - try vgg perception metric
# - focus prediction
#
#
# RCAN Results
# - Uses lots of resources as scale of image increases
# - Does not handle different scales well
# - not meant for restoration -
# To try
# - Apply pretrained model on a patch thats 48x48 then can judge if its worth making an approach to apply repeatedly to larger images.
# - train vdsr with a convolutional upscaling up front, attention, residuals.
#
# UNET results
# - Some sharpening but not drastic.  Not better than VDSR
# - Used 2x GPU mem than VDSR
#
# New Network results
# - Performs as well as VDSR qualitatively, need to check.
# - using Div2K gives better results (needs low learning rate)
# - try with L1 norm (less noise sensitive)
# - add upscale in the middle to allow more flexibility - nn.ConvTranspose2d(in_channels=C, out_channels=M, kernel_size=5, stride=2, padding=2, output_padding=1, bias=False)
# - add  with torch.no_grad():  to validation and prediction with the model to speed up computations.
#
#
# To Try
# - UNET or VDSR with MAXout nonlinear function.  Try different activation functions (mish,etc).
# - consistency error measure like fastai superres
# - provide input,target  pairs with no fuzziness in the training set.
# - Train exclusively on very sharp  images (DIV2K)
# - Predict focus as a segmentation in addition to enhancing
# - have 3 channel inputs (RGB or ??) and then have 1 channel output
# - provide frame-1,frame,frame+1 to predict frame
# - opposite of bottleneck - input resolution -> high res -> input res blocks.
# - combo of UNET and VDSR
# - attention?
# - combo of perception and mse measure
# - add validation set
# - sort dataset into hard cases and easy cases, making cases harder with time.  (train on easy cases first, then fine tune with harder cases)
# - make the camera model version of the data loader
# - use mse but give more error to perception
# - try reflection padding
#
#
#
#
#
#
#
# ## Share results
# - put out an example on youtube to allow comparison

# %% [markdown]
# # Project Documentation

# %%
from pathlib import Path
import os


project_base = "/media/SSD/superres/"
results_folder = "Results"
data_folder = "video_data"
model_folder = "checkpoint"

model_name_base = "TEST"

# %% [markdown]
# ## Experiment documentation

# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
print("NOTEBOOK_FULL_PATH:\n", NOTEBOOK_FULL_PATH)
# Out:
# NOTEBOOK_FULL_PATH:
#  /SSD_link/superres/Superresolution train New Network upscale PRelu L1 Div2 training-Copy1.ipynb

# %%
nb_path = Path(NOTEBOOK_FULL_PATH)
print(nb_path)

# Make result folder if it does not exist
result_path = Path(project_base, results_folder , nb_path.stem )
print(result_path)
os.makedirs(result_path, exist_ok=True)
# Out:
# /SSD_link/superres/Superresolution train New Network upscale PRelu L1 Div2 training-Copy1.ipynb
# /media/SSD/superres/Results/Superresolution train New Network upscale PRelu L1 Div2 training-Copy1

# %%
model_out_path=Path(project_base)/model_folder
print(model_out_path)
os.makedirs(model_out_path, exist_ok=True)
# Out:
# /media/SSD/superres/checkpoint

# %%
# Tie a result to a set of params.  Tie a set of params to a model.  Tie a model to a notebook.
# register the experiment to get a unique run id
# save all the results in a repository
# use github to do it?

# %%
#%reload_ext autoreload
#%autoreload 2
#%matplotlib inline


import cv2 
import numpy as np
import subprocess as sp
import time
from tqdm import tqdm, trange
import torch
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from torchvision.transforms import RandomHorizontalFlip,ColorJitter
from torchvision.transforms import Compose, CenterCrop, ToTensor, Resize, Grayscale,ToPILImage

import random
#from astropy.convolution import  Gaussian2DKernel, Tophat2DKernel,AiryDisk2DKernel


#import sys
#sys.path.insert(0, '/media/SSD/superres/pytorch-vdsr/')

#from vdsr import Net

import lpips #https://github.com/richzhang/PerceptualSimilarity

# %%
import torch.utils.data as data

from os import listdir
from os.path import join
from PIL import Image, ImageFilter
import numpy as np
import torchvision as vision

import numbers


torch.cuda.manual_seed(42)

# %% [markdown]
# Create a data loader
# - see https://github.com/2KangHo/vdsr_pytorch/blob/master/data.py
# - see https://github.com/2KangHo/vdsr_pytorch/blob/master/data_utils.py

# %%
import fnmatch

# %%
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg", ".bmp"])

def is_video_file(path, extensions = ("mp4",)):
    return path.lower().endswith(extensions)

def frame_sampler1(length, frame_sample_size):

    # calculate middle of video and take 'frame_sample_size' frames from middle
    middle = length // 2
    left_length = frame_sample_size//2
    right_length = frame_sample_size - left_length
    left = max(0,middle - left_length)
    right = min(length, middle + right_length)
          
    return list(range(left,right))



def frame_sampler2(length, frame_sample_size):
    return np.linspace(0, length, 3+min(frame_sample_size,length)).astype(int)[2:-1]


# Make this load still photos too, and have them added with frame = 0
def make_framelist(video_dir,frame_sample_size = 10, match_exp = "*.*"):
    instances = []
    for filename in listdir(video_dir):
        

        if fnmatch.fnmatch(filename, match_exp):
            filepath = os.path.join(video_dir,filename)
            #print(filename)

            if is_video_file(filepath):
                # open video file
                cap = cv2.VideoCapture(str(filepath))

                # get frame count
                length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

                cap.release()

                if frame_sample_size is not None:
                    samples = frame_sampler2(length, frame_sample_size)
                    # append fn and frame num to instances
                else:
                    samples = range(0,length)

                for frame in samples:
                    item = {"Filepath":filepath,"Type":"frame",  "Framenum":frame}
                    instances.append(item)

            elif is_image_file(filepath):
                # open image file
                img = cv2.imread(filepath)
                item = {"Filepath":filepath, "Type":"image"}
                instances.append(item)
            
    return instances

# %%
# get a list of all the data
instances = make_framelist("/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR",1)

# %%
instances
# Out:
# [{'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0185.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0054.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0193.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0687.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0618.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0019.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0507.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0330.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0099.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0619.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0078.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0229.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0065.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0597.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0127.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0775.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0409.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0675.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0714.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0774.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0573.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0559.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0348.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0100.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0524.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0488.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0093.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0473.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0028.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0296.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0414.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0641.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0086.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0792.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0283.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0411.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0230.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0275.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0642.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0194.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0096.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0036.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0327.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0770.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0357.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0523.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0299.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0557.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0367.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0159.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0370.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0018.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0104.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0196.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0050.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0639.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0167.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0465.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0640.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0241.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0141.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0073.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0669.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0314.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0733.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0290.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0359.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0336.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0291.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0388.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0622.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0542.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0741.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0366.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0504.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0075.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0771.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0484.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0304.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0440.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0315.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0708.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0298.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0579.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0266.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0260.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0433.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0216.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0495.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0664.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0322.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0358.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0136.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0446.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0268.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0691.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0154.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0243.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0021.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0623.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0313.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0586.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0079.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0735.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0262.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0345.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0218.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0353.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0769.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0476.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0598.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0752.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0672.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0651.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0609.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0577.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0456.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0701.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0500.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0748.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0088.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0017.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0662.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0535.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0413.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0089.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0048.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0285.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0645.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0481.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0113.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0090.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0544.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0341.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0306.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0477.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0120.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0590.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0499.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0381.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0372.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0404.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0153.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0422.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0363.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0562.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0115.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0558.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0098.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0244.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0163.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0055.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0536.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0606.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0762.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0284.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0109.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0616.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0447.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0338.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0681.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0537.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0656.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0015.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0541.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0379.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0788.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0530.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0750.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0204.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0402.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0037.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0024.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0041.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0264.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0703.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0720.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0497.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0731.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0649.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0332.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0525.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0608.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0273.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0023.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0683.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0390.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0316.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0563.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0395.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0483.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0056.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0128.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0308.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0164.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0309.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0319.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0178.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0668.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0773.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0070.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0376.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0742.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0135.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0172.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0116.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0420.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0082.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0355.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0117.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0354.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0754.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0394.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0035.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0755.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0765.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0002.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0760.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0432.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0257.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0712.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0709.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0751.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0462.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0203.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0463.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0531.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0529.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0108.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0068.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0430.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0062.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0776.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0428.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0378.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0780.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0605.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0434.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0179.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0715.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0130.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0593.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0294.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0251.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0238.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0261.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0192.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0106.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0146.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0034.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0415.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0126.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0494.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0453.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0058.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0794.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0210.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0568.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0406.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0277.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0047.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0195.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0043.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0596.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0369.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0690.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0026.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0412.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0053.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0101.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0132.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0253.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0466.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0201.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0666.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0271.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0512.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0581.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0312.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0589.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0152.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0206.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0680.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0587.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0526.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0040.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0493.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0501.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0317.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0724.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0727.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0377.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0030.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0713.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0628.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0555.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0374.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0519.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0219.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0627.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0779.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0039.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0772.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0565.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0166.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0005.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0122.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0492.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0143.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0351.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0389.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0234.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0027.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0148.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0658.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0561.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0397.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0410.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0510.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0588.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0610.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0486.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0653.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0583.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0629.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0139.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0667.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0696.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0333.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0280.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0448.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0187.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0716.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0200.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0114.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0615.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0503.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0091.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0223.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0491.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0643.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0611.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0042.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0548.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0781.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0729.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0149.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0162.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0459.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0594.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0424.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0009.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0506.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0759.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0717.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0282.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0461.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0475.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0511.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0368.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0572.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0688.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0151.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0147.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0066.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0480.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0278.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0580.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0007.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0279.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0490.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0231.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0110.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0728.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0749.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0217.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0142.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0564.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0686.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0613.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0441.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0226.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0364.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0111.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0072.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0417.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0454.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0131.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0272.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0532.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0063.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0699.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0479.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0095.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0725.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0516.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0274.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0436.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0582.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0242.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0103.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0171.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0722.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0753.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0212.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0046.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0416.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0076.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0784.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0057.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0240.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0553.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0539.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0138.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0342.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0245.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0197.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0455.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0442.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0289.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0697.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0778.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0263.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0025.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0307.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0360.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0134.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0567.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0399.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0431.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0599.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0515.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0235.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0215.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0513.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0097.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0661.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0646.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0084.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0633.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0418.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0538.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0670.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0249.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0202.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0521.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0158.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0496.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0768.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0443.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0403.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0205.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0458.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0648.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0371.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0723.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0457.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0305.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0451.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0684.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0181.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0632.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0069.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0408.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0575.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0292.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0612.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0636.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0006.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0744.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0286.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0288.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0328.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0246.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0160.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0625.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0081.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0540.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0707.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0186.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0324.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0144.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0517.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0265.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0677.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0118.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0362.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0764.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0145.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0471.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0155.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0237.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0183.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0689.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0520.png',
# ...
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0137.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0297.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0693.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0387.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0585.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0665.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0008.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0485.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0325.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0425.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0450.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0401.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0730.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0747.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0038.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0427.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0300.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0738.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0509.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0592.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0344.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0657.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0761.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0591.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0543.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0184.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0695.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0207.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0077.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0156.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0614.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0125.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0620.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0704.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0012.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0224.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0710.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0444.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0318.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0310.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0112.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0464.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0085.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0552.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0736.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0124.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0302.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0644.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0013.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0400.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0685.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0545.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0051.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0071.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0603.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0346.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0482.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0170.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0350.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0105.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0647.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0569.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0734.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0604.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0498.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0213.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0659.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0435.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0303.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0250.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0797.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0233.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0437.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0236.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0169.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0189.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0554.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0660.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0800.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0129.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0789.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0631.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0269.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0221.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0064.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0571.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0574.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0607.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0785.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0706.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0676.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0391.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0361.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0352.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0533.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0199.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0550.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0790.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0793.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0795.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0393.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0694.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0551.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0150.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0782.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0740.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0439.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0339.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0671.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0407.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0123.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0067.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0239.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0087.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0429.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0398.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0180.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0617.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0060.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0255.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0044.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0426.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0600.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0698.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0140.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0758.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0222.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0059.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0783.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0396.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0705.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0692.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0796.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0638.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0094.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0356.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0478.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0508.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0601.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0556.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0214.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0175.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0326.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0380.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0347.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0489.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0022.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0188.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0165.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0335.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0365.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0737.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0209.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0375.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0711.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0031.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0799.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0382.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0329.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0061.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0334.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0074.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0624.png',
#   'Type': 'image'},
#  {'Filepath': '/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR/0182.png',
#   'Type': 'image'}]

# %%
def load_frame(instance):
    
    path = instance["Filepath"]
    
    if instance["Type"] == "frame":
        
        frame = instance["Framenum"]
        cap = cv2.VideoCapture(path)
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame-1)
        ret, img = cap.read()
        if ret==0:
            print("Error with:",instance)
    elif instance["Type"] == "image":
        img = cv2.imread(path)
    # convert to PIL RGB
    im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    return Image.fromarray(im_rgb)

# %%
def tophat2D(r):
    
    d=2*int(r)+1
    Y, X = np.ogrid[:d, :d]
    c=int(r)
    k = (np.sqrt((X-c)**2 +  (Y-c)**2) <= r)*1 
    
    return k/k.sum()

# %%
class RescaleCrop(object):


    def __init__(self, crop_size ,kernel_width):
        
        if isinstance(crop_size, numbers.Number):
            self.crop_size = (int(crop_size), int(crop_size))
        else:
            self.crop_size = crop_size 
        
        self.kernel_width = kernel_width
        

    
        

    def __call__(self, img):
        
        
        # Ideal steps
        # Crop with proportional scale, to simulate images of different input resolutions (if thats a requirement)
        # This crop should leave some edges of the image to allow blurring with kernel beyond final size
        # Blur the image 
        # If different randomly picked blurring kernels are used, they should have equivalent blurring power.
        
        h_size,v_size = img.size
        
        #print("im size:", img.size)
        
        # Resize down to a size a bit larger than final size to allow proper blurring
        v_wanted = int(self.crop_size[0]+self.kernel_width+1)
        h_wanted = int(self.crop_size[1]+self.kernel_width+1)
        
        #print("im wanted:", (h_wanted, v_wanted))
        
        h_scale = h_wanted/h_size
        v_scale = v_wanted/v_size
        
        scale = max(h_scale, v_scale)
        
        #print("scales=",(h_scale, v_scale))
        
        #print("new size=",(int(h_size*scale), int(v_size*scale)))
        img = img.resize((int(h_size*scale), int(v_size*scale)))
        
        img = CenterCrop((v_wanted,h_wanted))(img) 

        
        return img

# %%
def cv_center_crop(img,output_size):
        if isinstance(output_size, numbers.Number):
            output_size = (int(output_size), int(output_size))
            
        
        image_height = img.shape[0]
        image_width = img.shape[1]
        
        crop_height, crop_width = output_size
        crop_top = max(0,int(round((image_height - crop_height) / 2.)))
        crop_left = max(0,int(round((image_width - crop_width) / 2.)))
        #print("input:",img.shape)
        #print("output:",output_size)
        #print("crop:",crop_top,crop_top+output_size[0],crop_left,crop_left+output_size[1])
        return img[crop_top:crop_top+output_size[0],crop_left:crop_left+output_size[1]]

# %%
def create_circular_mask(h, w, slope=0.01, center=None, radius=None, scale=1.0):

    if center is None: # use the middle of the image
        center = (int(w/2), int(h/2))
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])

    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((scale*(X - center[0]))**2 + ((Y-center[1])/scale)**2)

    mask = np.minimum((np.maximum(dist_from_center-radius,0)*slope)**(0.5),1.0)
    return mask

# %%
def cv_disk_blur(img_cv, kernel_width):
    k = tophat2D(int(kernel_width)/2.0)
    return cv2.filter2D(img_cv, cv2.CV_32F, k)

# %%
def pil_disk_blur(img,kernel_width):
    img_cv = cv_disk_blur(np.array(img),kernel_width)
    img_cv = cv2.normalize(img_cv, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
    return Image.fromarray(img_cv)

# %%
class Multifuz(object):


    def __init__(self, crop_size ,kernel_a, kernel_b, quality, slope, radius, scale, center):
        
        if isinstance(crop_size, numbers.Number):
            self.crop_size = (int(crop_size), int(crop_size))
        else:
            self.crop_size = crop_size 
        
        self.kernel_a = kernel_a
        self.kernel_b = kernel_b
        self.quality = quality.item()
        self.slope = slope
        self.radius = radius
        self.scale = scale
        self.center = center
        

    
        

    def __call__(self, img):
        
        img_cv = np.array(img)
        d = img_cv .shape
        dim = (d[1], d[0])
        height = d[0]
        width = d[1]
        color = len(d)-2
        
        
        #blur kernel A
        
        k = tophat2D(int(self.kernel_a)/2.0)
        img_cv_blurA = cv2.filter2D(img_cv, cv2.CV_32F, k)
        img_cv_blurA = cv_center_crop(img_cv_blurA,self.crop_size)
        
        #blur kernel B
        k = tophat2D(int(self.kernel_b)/2.0)
        img_cv_blurB = cv2.filter2D(img_cv, cv2.CV_32F, k)
        img_cv_blurB = cv_center_crop(img_cv_blurB,self.crop_size)
        
        #add them with a mask
        # Normalize the alpha mask to keep intensity between 0 and 1
        
        alpha = create_circular_mask(h=self.crop_size[0], w=self.crop_size[1], slope=self.slope,center=self.center,
                                     radius=self.radius, scale = self.scale)*1.0
        
        if color ==1:
            alpha=np.reshape(alpha, (self.crop_size[0],self.crop_size[1],-1))
            alpha=np.broadcast_to(alpha,[self.crop_size[0],self.crop_size[1],3])
        
        #alpha = alpha.astype(float)/255
        
        # Multiply the foreground with the alpha matte
        
        
        
        img_cv_blurA = cv2.multiply(img_cv_blurA, alpha, dtype=cv2.CV_32F )
        # Multiply the background with ( 1 - alpha )

        
        img_cv_blurB = cv2.multiply(img_cv_blurB, 1.0 - alpha, dtype=cv2.CV_32F)
        # Add the masked foreground and background.

        #img_cv = img_cv_blurA
        img_cv = cv2.add(img_cv_blurA, img_cv_blurB, dtype=cv2.CV_32F)
        
        img_cv = cv2.normalize(img_cv, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
        
        
        
    
        #Center Crop
        #img_cv = cv_center_crop(img_cv,self.crop_size)
        
        #Jpeg compression (for adding artifacts)
        
        is_success, im_buf_arr = cv2.imencode(".jpg", img_cv,params = [cv2.IMWRITE_JPEG_QUALITY,self.quality])
        
        
        img_cv = cv2.imdecode(im_buf_arr,flags=cv2.IMREAD_COLOR)
        
        
        img= Image.fromarray(img_cv)
        return img

# %%
#test the Multifuz transform
im=load_frame(instances[10])
#im = Grayscale(num_output_channels=1)(im)
im = RescaleCrop(crop_size=(480,720),kernel_width=10)(im)
im_res = Multifuz(crop_size = (480,720),
                  center=(360,240),
                  kernel_a=2, 
                  kernel_b=10,
                  quality=np.int16(22), 
                  slope=.1,
                 radius=50,
                 scale=1)(im)
print(im.size,im_res.size)
type(im_res)
im_res
# Out:
# (731, 491) (720, 480)
# <PIL.Image.Image image mode=RGB size=720x480 at 0x7F2E7648C040>

# %%
input_transform
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8137cd3b1e36> in <module>
# ----> 1 input_transform
#
# NameError: name 'input_transform' is not defined

# %%
class DatasetFromVideoFolder(data.Dataset):
    def __init__(self, video_dir,crop_size,frame_sample_size=10,max_kernel=10,Flip_hor=True,
                 Rand_bright_contrast=True, inport_transform=None, target_transform=None, match_exp="*.*", **camera_params):
        
        #  add_noise=None, noise_std=3.0, Flip_hor=False,Rand_bright_contrast=False, kernel_width=10

        super(DatasetFromVideoFolder, self).__init__()
        self.video_frames = make_framelist(video_dir,frame_sample_size,match_exp)
        
        self.Flip_hor = Flip_hor
        self.Rand_bright_contrast = Rand_bright_contrast
        self.crop_size = crop_size
        self.max_kernel = max_kernel
        self.target_transform = target_transform
        self.camera_params = camera_params
        self.input_transform = input_transform
        
    def camera_transform(self,img_hr):
        
        # go through the parameters and simulate the camera
        width, height = img_hr.size
               
        crop_top = max(0,int(round((height - self.crop_size[0]) / 2.)))
        crop_bottom = crop_top + self.crop_size[0]
        crop_left = max(0,int(round((width - self.crop_size[1]) / 2.)))
        crop_right = crop_left + self.crop_size[1]
        
        camera_specs = {}
        camera_specs["crop_size"] = np.int16(self.crop_size)
        
        camera_specs["center"] = np.int16((random.uniform(crop_left, crop_right),random.uniform(crop_top, crop_bottom)))
        
        camera_specs["scale"] = np.float32(random.uniform(0.5,2))
       
        
        camera_specs["kernel_a"] = np.float32(random.uniform(*self.camera_params["kernel_range"]))
        camera_specs["kernel_b"] = np.float32(random.uniform(*self.camera_params["kernel_range"]))
        camera_specs["quality"] = np.int16(random.uniform(*self.camera_params["quality_range"]))
        camera_specs["slope"] = np.float32(random.uniform(*self.camera_params["slope_range"]))
        camera_specs["radius"] = np.float32(random.uniform(*self.camera_params["radius_range"])*max(self.crop_size[0],self.crop_size[1]))
        
        img_lr = Multifuz(**camera_specs)(img_hr)
        return img_lr, camera_specs

    def __getitem__(self, index):
        img_hr = load_frame(self.video_frames[index])
        if self.crop_size is not None:
            img_hr = RescaleCrop(self.crop_size,self.max_kernel )(img_hr)
        
        if self.Flip_hor:
            img_hr = RandomHorizontalFlip()(img_hr)
        
        if self.Rand_bright_contrast:
            img_hr = ColorJitter(brightness=.2, contrast=.2)(img_hr)
        
        

        
        # go through the parameters and simulate the camera
        img_lr,camera_specs = self.camera_transform(img_hr)
            
        
        if self.input_transform:
            img_lr = self.input_transform(img_lr)
        
        if self.target_transform:
            img_hr = self.target_transform(img_hr)
            
        #print(camera_specs)
        return img_lr, img_hr, camera_specs

    def __len__(self):
        return len(self.video_frames)

# %%
def input_transform():        
    return Compose([        
        Grayscale(num_output_channels=1),
        ToTensor(),
    ])



def target_transform(crop_size):
    return Compose([
        Grayscale(num_output_channels=1),
        CenterCrop(crop_size),
        ToTensor(),
    ])

# %%
train_dir = "/home/filip/SSD_link/superres/DIV2K/DIV2K_train_HR"
#train_dir = "/home/filip/SSD_link/superres/video_data/train_data"
frame_sample_size =10
batch_size = 4 # Make 4 For FP16, 480x720 size images
crop_size = (480,720)
#crop_size = (256,256)
kernel_range=(1,16)
quality_range=(30,90) 
slope_range=(0.001, 0.1)
radius_range=(.25,.75)
scale_range=(1/2,2)
Flip_hor=True
Rand_bright_contrast=True

# %%
train_set = DatasetFromVideoFolder(train_dir,crop_size,frame_sample_size,
                                   input_transform=input_transform(),
                                   target_transform=target_transform(crop_size),
                                   Flip_hor=Flip_hor,
                                   Rand_bright_contrast=Rand_bright_contrast,
                                   kernel_range=kernel_range,
                                   quality_range=quality_range,
                                   slope_range=slope_range,
                                   radius_range=radius_range,
                                   scale_range=scale_range,
                                   max_kernel=10
                            )
training_data_loader = DataLoader(dataset=train_set, num_workers=0, batch_size=batch_size, shuffle=True)

# %%
valid_dir = "/home/filip/SSD_link/superres/DIV2K/DIV2K_valid_HR"
#frame_sample_size =10
#batch_size = 4 # Make 4 For FP16, 480x720 size images
#crop_size = (480,720)

kernel_range=(1,16)
quality_range=(30,99) 
slope_range=(0.001, 0.1)
radius_range=(.25,.75)
scale_range=(1/2,2)
Flip_hor=False
Rand_bright_contrast=False
match_exp = "*.*"

# %%
valid_set = DatasetFromVideoFolder(valid_dir,crop_size,frame_sample_size,
                                   input_transform=input_transform(),
                                   target_transform=target_transform(crop_size),
                                   Flip_hor=Flip_hor,
                                   Rand_bright_contrast=Rand_bright_contrast,
                                   kernel_range=kernel_range,
                                   quality_range=quality_range,
                                   slope_range=slope_range,
                                   radius_range=radius_range,
                                   scale_range=scale_range,
                                   max_kernel=10,
                                   match_exp=match_exp,
                            )
valid_data_loader = DataLoader(dataset=valid_set, num_workers=0, batch_size=batch_size, shuffle=False)

# %%
# measurement of blur of an image
def variance_of_laplacian(image):
    # compute the Laplacian of the image and then return the focus
    # measure, which is simply the variance of the Laplacian
    return cv2.Laplacian(image, cv2.CV_64F).var()


def show_batch(dataloader,size = 8):

    inputs, outputs, camera_specs = next(iter(dataloader))
    #print(inputs.shape)
    inputs = inputs.numpy().transpose((0, 2, 3, 1))
    outputs = outputs.numpy().transpose((0, 2, 3, 1))
    #print(camera_specs)
    
    #mean = np.array([0.485, 0.456, 0.406])
    #std = np.array([0.229, 0.224, 0.225])
    #inputs = inputs*std + mean
    #outputs = outputs*std + mean
    w,h = 2*size, 4*size
    fig=plt.figure(figsize=(w, h))
    columns = 2
    rows = 4
    ax=[]
    
    for i in range(0, rows):
        blur_measure_input = variance_of_laplacian((inputs[i]*255).astype(np.uint8))
        blur_measure_output = variance_of_laplacian((outputs[i]*255).astype(np.uint8))
        ax.append(fig.add_subplot(rows, columns, 2*i+1))
        ax[-1].set_title('Blur: '+str(blur_measure_input))
        plt.imshow((inputs[i]*255).astype(np.uint8),cmap='gray')
        ax.append(fig.add_subplot(rows, columns, 2*i+2))
        ax[-1].set_title('Blur: '+str(blur_measure_output))
        plt.imshow((outputs[i]*255).astype(np.uint8),cmap='gray')
    plt.show()

# %%
show_batch(training_data_loader,size =8)

# %%
show_batch(valid_data_loader,size =8)

# %% [markdown]
# # NEW CNN

# %%
import torch.nn as nn

class NEWNet2(nn.Module):
    def __init__(self, c1, c2):
        super(NEWNet2, self).__init__()   
        
        self.p1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=c1, kernel_size=3, stride=1, padding=1, bias=False),
            nn.PReLU(),
            nn.Conv2d(in_channels=c1, out_channels=c1, kernel_size=3, stride=1, padding=1, bias=True),
            nn.PReLU(),
            nn.Conv2d(in_channels=c1, out_channels=c1, kernel_size=3, stride=1, padding=1, bias=True),
            nn.PReLU()
        )
        
        self.p2 = nn.Sequential(
            nn.Conv2d(in_channels=c1, out_channels=c2, kernel_size=1, stride=1, padding=0, bias=True),
            nn.PReLU(),
            nn.Conv2d(in_channels=c2, out_channels=c2, kernel_size=3, stride=1, padding=1, bias=True),
            nn.PReLU(),
            nn.Conv2d(in_channels=c2, out_channels=c1, kernel_size=1, stride=1, padding=0, bias=True)
        )
        self.prelu = nn.PReLU()
        self.convf = nn.Conv2d(in_channels=c1, out_channels=1, kernel_size=3, stride=1, padding=1, bias=True)
        
        
    def forward(self, x):    
        residual = x
        x = self.p1(x)
        skip1 = x
        x = self.p2(x)
        x = x.add_(skip1)
        x = self.prelu(x)
        x = self.convf(x)
        out = torch.add(x,residual)
        return out

# %% [markdown]
# # build the model

# %%
#model = NEWNet2(c1=64,c2=128)
model = NEWNet2(c1=64,c2=128)
model.cuda()

# %%
num_pixels = crop_size[0] * crop_size[1]

# %%
def loss_scaler(im):
    # scale to -1,1 and convert to 3 channel (greyscale to RBG)
    return (im * 2 - 1).expand(-1, 3, -1, -1)

# %%
class Pixel_Loss(torch.nn.Module):
    
    def __init__(self,num_pixels):
        super(Pixel_Loss,self).__init__()
        self.lossfn = nn.MSELoss(reduction = 'mean')
        
        self.percep_loss_fn = lpips.LPIPS(net='alex').cuda()


        self.num_pixels = num_pixels
    #def forward(self,x,y):
        
     #   return self.num_pixels*(self.lossfn.forward(x,y))
    
    
    def forward(self,x,y):
        
        totloss = torch.mean(self.percep_loss_fn.forward(loss_scaler(x),loss_scaler(y)))
        #print("perceptual:",totloss)
        
        totloss.add_(50 * self.lossfn.forward(x,y))
        #print("total:",totloss)
        
        return totloss

# %%
#criterion = Pixel_Loss(num_pixels)
criterion = nn.L1Loss(reduction = 'mean')

# %%
init_lr = .001
lr_step = 3
gradient_clip = 0.4
epochs = 18

# %%
#optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=1e-4)
optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=0)

# %%
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, 
                                          max_lr=0.01,
                                          steps_per_epoch=len(training_data_loader),
                                          epochs=epochs)

# %%
def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10**0.5 every 3 epochs"""
    lr = init_lr * (0.1 ** (.5*(epoch // lr_step)))
    return lr

# %%
def save_checkpoint(experiment, model, epoch, valid_error):

    model_out_str = str(model_out_path/(model_name_base+"_epoch_{}.pth")).format(epoch)
    
    state = {"experiment": experiment, "epoch": epoch ,"model": model, "valid_error": valid_error}

    torch.save(state, model_out_str)

    print("Checkpoint saved to {}".format(model_out_str))

# %%
import datetime
from torch.cuda.amp import autocast
from torch.cuda.amp import GradScaler
#import kornia

# %%
from torch.optim.swa_utils import AveragedModel
swa_model = torch.optim.swa_utils.AveragedModel(model)

# %%
def trainfp16(training_data_loader, optimizer, scheduler, model, criterion, epoch,scaler):
    dt = str(datetime.datetime.now())
    print("Start Time:", dt)
    
    lr = adjust_learning_rate(optimizer, epoch-1)

    for param_group in optimizer.param_groups:
        param_group["lr"] = lr

    print("Epoch = {}, lr = {}".format(epoch, optimizer.param_groups[0]["lr"]))

    model.train()
    cum_loss2=0
    cum_loss = 0
    ct=0
    ct2=0

    pbar = tqdm(total=8*len(training_data_loader))
    for ct in range(8):
        for iteration, batch in enumerate(training_data_loader, 1):
            input, target = batch[0], batch[1]


            input = input.cuda()

            target = target.cuda()

            optimizer.zero_grad()

            # Runs the forward pass with autocasting.
            with autocast():
                output = model(input)
                loss = criterion(output, target)




            scaler.scale(loss).backward()
            #loss.backward() 

            # Unscales the gradients of optimizer's assigned params in-place
            #scaler.unscale_(optimizer)

            #nn.utils.clip_grad_norm_(model.parameters(),gradient_clip) 

            #optimizer.step()
            scaler.step(optimizer)

            if epoch>1:
                swa_model.update_parameters(model)

            # Updates the scale for next iteration.
            scaler.update()

            #scheduler.step()

            cum_loss = cum_loss + loss.data

            ct = ct +batch_size



            pbar.update(1)
    pbar.close()    
   
    print("Epoch Loss:", cum_loss/ct)

# %%
def validatefp16(valid_data_loader, model, criterion, loop=10):

    model.eval()
    cum_loss2=0
    cum_loss = 0
    ct=0
    ct2=0
    with torch.no_grad():
        for r in trange(loop):
            for iteration, batch in enumerate(valid_data_loader, 1):
                input, target, camera_specs = batch[0], batch[1], batch[2]


                input = input.cuda()

                target = target.cuda()

                
                # Runs the forward pass with autocasting.
                with autocast():
                    output = model(input)
                    loss = criterion(output, target)


                cum_loss = cum_loss + loss.data


                ct = ct +batch_size





        print("===> Epoch Validation Loss: {:.10f}".format(cum_loss/ct) )
    
    return (cum_loss/ct).item()

# %%
#model = torch.load("/media/SSD/superres/checkpoint/NEWCNN_epoch_12.pth")["model"]

# %%
#validatefp16(valid_data_loader, model, criterion, loop=1)

# %% [markdown]
# f1 = "/media/SSD/superres/checkpoint/NEWCNN_epoch_"
# f3 = ".pth"
# lst =[]
# for i in range(1,13):
#     model = torch.load(f1+str(i)+f3)["model"]
#     lst.append(validatefp16(valid_data_loader, model, criterion, loop=10))
#     print(lst)

# %%
# Creates a GradScaler once at the beginning of training for mixed precision
scaler = GradScaler()


for epoch in range(1, epochs+1):
        trainfp16(training_data_loader, optimizer, scheduler, model, criterion, epoch,scaler)
        valid_error = validatefp16(valid_data_loader, model, criterion)
        save_checkpoint(NOTEBOOK_FULL_PATH, model, epoch, valid_error)

# %%
init_lr = .001
lr_step = 6
gradient_clip = 0.4
epochs = 54

# %%
for epoch in range(19, epochs+1):
        trainfp16(training_data_loader, optimizer, scheduler, model, criterion, epoch,scaler)
        valid_error = validatefp16(valid_data_loader, model, criterion)
        save_checkpoint(NOTEBOOK_FULL_PATH, model, epoch, valid_error)

# %% [markdown]
# Function that takes in a .mp4 video file and applies intrinsic matrix and distortion coefficients to undistort a video.  It also preserves the sound. it uses ffmpeg for some processing as well as opencv cv2 library.

# %%
# Define the colorization function
# We'll reuse the Cb and Cr channels from bicubic interpolation
def colorize_cv(y, ycbcr): 
    img = np.zeros((y.shape[0], y.shape[1], 3), np.uint8)
    img[:,:,0] = y
    img[:,:,1] = ycbcr[:,:,1]
    img[:,:,2] = ycbcr[:,:,2]
    img = cv2.cvtColor(img, cv2.COLOR_YCrCb2BGR)
    return img

# %%
def decolorize_cv(frame):
    im_ycbcr = cv2.cvtColor(frame, cv2.COLOR_BGR2YCR_CB)
    im_b_y = im_ycbcr[:,:,0].astype(float)
    im_grey = im_b_y/255.0
    return im_grey, im_ycbcr

# %%
from torch.cuda.amp import autocast
def superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=True,bitrate= "12000k",errorfile = None):
    
    model = model.cuda()
    #torch.set_grad_enabled(False)
    model.eval()
    
    cap = cv2.VideoCapture(str(infile))
    
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)
    
    success_flag = False
    
    print("Original File:", str(infile))
    print("frames=",length,"\nwidth=",width,"\nheight=",height,"\nfps=",fps)
    
    

    new_height = int(height*factor)
    new_width = int(width*factor)
    
    print("\nProcess File:", str(outfile))
    print("factor:",factor,"\nwidth=",new_width, "\nheight=",new_height,"\nbitrate=",bitrate)
    
    

    dimension = '{}x{}'.format(new_width, new_height)  #ffmpeg uses bicubic as default scaling alg
    f_format = 'bgr24' # remember OpenCV uses bgr format




    command = ['ffmpeg',
            '-y',
            '-f', 'rawvideo',
            '-vcodec','rawvideo',
            '-s', dimension,
            '-pix_fmt', 'bgr24',
            '-r', str(fps),
            '-i', '-',
            '-i', str(infile),
            '-c:v', 'h264',
            '-c:a', 'aac',

            '-map','0:v:0',
            '-map','1:a:0',
            '-shortest',
            '-b:v', bitrate, 
            str(outfile) ]


    if errorfile is not None:
        ef = open(error_file,"w+")
        p = sp.Popen(command, stdin=sp.PIPE, stderr=ef)
    else:
        p = sp.Popen(command, stdin=sp.PIPE)

    # Full processing with a stream instead of a temp file for video
    pbar = tqdm(total=length)
    while(cap.isOpened()):




        # Capture frame-by-frame
        ret, frame = cap.read()
        if ret == True:
            
            if (factor != 1.0):
                frame = cv2.resize(frame, (new_width, new_height), interpolation=cv2.INTER_LANCZOS4)
            
            if channels == 1:
                im_input, im_b_ycbcr = decolorize_cv(frame)

                im_input = Variable(torch.from_numpy(im_input).float()).view(1, -1, im_input.shape[0], im_input.shape[1])
                im_input = im_input.cuda()

                with autocast():
                    out = model(im_input)
                out = (out*255.0).clamp(0,255)

                out = out.cpu()

                im_h_y = out.data[0].numpy().astype(np.float32)

                im_h_y = im_h_y[0,:,:]

                im_h = colorize_cv(im_h_y, im_b_ycbcr)
            elif channels == 3:
                im_input = frame/255.
                im_input = Variable(torch.from_numpy(im_input).float()).\
                view(1, 3, im_input.shape[0], im_input.shape[1])
        
  
                im_input = im_input.cuda()
    
                
                
                with autocast():
                    out = model(im_input)
                out = (out*255.0).clamp(0,255)

                out = out.cpu()
                
                im_h = out.data[0].view(im_input.shape[2], im_input.shape[3],3).numpy().astype(np.uint8)

                #im_h = out.data[0].numpy().astype(np.float32)

            
                

            p.stdin.write(im_h.tobytes())


            if display:
                cv2.imshow('Processed',im_h)
                time.sleep(10)
                #cv2.imshow('Orig',frame)
            pbar.update(1)
            # Press Q on keyboard to  exit
            if cv2.waitKey(25) & 0xFF == ord('q'):
                success_flag = False
                break
        # Break the loop
        else:
            success_flag = True
            break
    # When everything done, release the video capture object

    pbar.close()

    p.stdin.close()
    p.wait()

    cap.release()

    # Closes all the frames
    cv2.destroyAllWindows()
    
    return success_flag

# %% [markdown]
# # compare to benchmarks

# %%
from PIL import Image
import math
import matplotlib.pyplot as plt

# %%
# Here is the function for PSNR calculation
def PSNR(pred, gt, shave_border=0):
    height, width = pred.shape[:2]
    pred = pred[shave_border:height - shave_border, shave_border:width - shave_border]
    gt = gt[shave_border:height - shave_border, shave_border:width - shave_border]
    imdff = pred - gt
    rmse = math.sqrt(np.mean(imdff ** 2))
    if rmse == 0:
        return 100
    return 20 * math.log10(255.0 / rmse)

# %%
# Define the colorization function
# We'll reuse the Cb and Cr channels from bicubic interpolation
def colorize(y, ycbcr): 
    img = np.zeros((y.shape[0], y.shape[1], 3), np.uint8)
    img[:,:,0] = y
    img[:,:,1] = ycbcr[:,:,1]
    img[:,:,2] = ycbcr[:,:,2]
    img = Image.fromarray(img, "YCbCr").convert("RGB")
    return img

# %%
def decolorize(x):
    x_ycbcr = cv2.cvtColor(x, cv2.COLOR_BGR2YCR_CB)
    x_y = x_ycbcr[:,:,0].astype(float)
    return x_y, x_ycbcr

# %%
percept_loss= Pixel_Loss(num_pixels)

# %%
def display_PSNR(im_gt, im_b, im_in, model,channels=1, display=True):
    

    # Convert the images into YCbCr mode and extraction the Y channel (for PSNR calculation)
    im_gt_ycbcr = np.array(im_gt.convert("YCbCr"))
    im_b_ycbcr = np.array(im_b.convert("YCbCr"))
    im_in_ycbcr = np.array(im_in.convert("YCbCr"))
    
    im_gt_y = im_gt_ycbcr[:,:,0].astype(float)
    im_b_y = im_b_ycbcr[:,:,0].astype(float)
    im_in_y = im_in_ycbcr[:,:,0].astype(float)
    
    #psnr_bicubic = PSNR(im_gt_y, im_b_y)
    #psnr_input = PSNR(im_gt_y, im_in_y)
    psnr_bicubic = PSNR(np.array(im_gt),np.array( im_b))
    psnr_input = PSNR(np.array(im_gt), np.array(im_in))
    
    im_i_ycbcr = np.array(im_in.convert("YCbCr"))
    im_i_y = im_i_ycbcr[:,:,0].astype(float)
        
    # Prepare for the input, a pytorch tensor
    if channels == 1:
        im_input = im_i_y/255.
        im_input = Variable(torch.from_numpy(im_input).float()).\
        view(1, -1, im_input.shape[0], im_input.shape[1])
    
    if channels ==3:
        im_input = np.array(im_in)/255.0
        #im_input = np.array(im_in)
        im_input = Variable(torch.from_numpy(im_input).float()).\
        view(1, 3, im_input.shape[0], im_input.shape[1])
        
    #print("im_input.shape=",im_input.shape)    
    im_input = im_input.cuda()
    
    with autocast():
        out = model(im_input)
    
    out = (out*255.0).clamp(0,255)
    
    out = out.cpu()
    
    if channels == 1:
        im_y = out.data[0].numpy().astype(np.float32)
        im_h_y = im_y[0,:,:]
        im_h = np.array(colorize(im_h_y, im_b_ycbcr))

    elif channels ==3:
        #print("out[0]=",out[0].shape)
        #print("out.data[0]=",out.data[0].shape)
        #print("im_input.shape=",im_input.shape)
        im_h = out.data[0].view(im_input.shape[2], im_input.shape[3],3).numpy().astype(np.uint8)
        #print("im.h.shape=",im_h.shape)
        im_h_y, _ = decolorize(im_h)
        
    
    # Calculate the PNSR for prediction
    #psnr_predicted = PSNR(im_gt_y, im_h_y)
    psnr_predicted = PSNR(np.array(im_gt), np.array(im_h))
    
    
    # Calculate the PNSR different between bicubic interpolation and vdsr prediction
    
    
    
    blur_measure_gt = variance_of_laplacian((im_gt_y).astype(np.uint8))
    blur_measure_bicubic = variance_of_laplacian((im_b_y).astype(np.uint8))
    blur_measure_input = variance_of_laplacian((im_i_y).astype(np.uint8))
    blur_measure_vdsr = variance_of_laplacian((im_h_y).astype(np.uint8))
    
    #percept_loss_input = percept_loss.forward(ToTensor()(im_gt),ToTensor()(im_in))
    #percept_loss_bicubic = percept_loss.forward(ToTensor()(im_gt),ToTensor()(im_b))
    #percept_loss_predict = percept_loss.forward(ToTensor()(im_gt),ToTensor()(im_h))
    
    # Colorize the grey-level image and convert into RGB mode

    im_gt = Image.fromarray(im_gt_ycbcr, "YCbCr").convert("RGB")
    im_b = Image.fromarray(im_b_ycbcr, "YCbCr").convert("RGB")
    
    if display:
    
        print('psnr for bicubic is {}dB'.format(psnr_bicubic))
        print('psnr for input is {}dB'.format(psnr_input))
        
        print('psnr for Model is {}dB'.format(psnr_predicted))
        print("PSNR improvement is {}dB".format(psnr_predicted - psnr_input))

        print("Sharpness Measurement GroundTruth:",blur_measure_gt)
        print("Sharpness Measurement Bicubic:",blur_measure_bicubic)
        print("Sharpness Measurement Input:",blur_measure_input)
        print("Sharpness Measurement Model:",blur_measure_vdsr)
        
        #print('perception loss for bicubic is {}'.format(percept_loss_bicubic))
        #print('perception loss for input is {}'.format(percept_loss_input))
        
        #print('perception loss for Model is {}'.format(percept_loss_predict))

        # Result visualization
        fig = plt.figure(figsize=(18, 16), dpi= 80)
        ax = plt.subplot(151)
        ax.imshow(im_gt)
        ax.set_title("GT")

        ax = plt.subplot(152)
        ax.imshow(im_b)
        ax.set_title("Bicubic")

        ax = plt.subplot(153)
        ax.imshow(im_in)
        ax.set_title("Input")

        ax = plt.subplot(154)
        ax.imshow(im_h)
        ax.set_title("Output(Model)")
        
        
        ax = plt.subplot(155)
        ax.imshow(np.clip(im_h-im_in +128,0,255))
        ax.set_title("Model-Input")
        plt.show()
    
    return im_h, psnr_bicubic, psnr_predicted

# %%
#model = torch.load("/media/SSD/superres/checkpoint/VDNEW2_epoch_15.pth")["model"]

# %%
# Load the groundtruth image and the low-resolution image (downscaled with a factor of 4)
im_gt = Image.open("/media/SSD/superres/pytorch-vdsr/Set5/butterfly_GT.bmp").convert("RGB")
im_b = Image.open("/media/SSD/superres/pytorch-vdsr/Set5/butterfly_GT_scale_4.bmp").convert("RGB")



im_b2 = pil_disk_blur(im_gt,6)

# %%
display_PSNR(im_gt, im_b, im_b2, model, channels=1);

# %%
# Make this load still photos too, and have them added with frame = 0
def test_results(test_dir,scale, channels=1, display = False):
    instances = []
    psnr_bicubic_sum = 0
    psnr_model_sum = 0
    ct = 0
    
    for filename in listdir(test_dir):
        filepath = os.path.join(test_dir,filename)
        #print(filepath)
                
        if is_image_file(filepath):
            im_gt = Image.open(filepath).convert("RGB")
            #print(im_gt.size)
            
            (height, width) = im_gt.size
            im_b = im_gt.resize((int(height/scale), int(width/scale)), resample = Image.BICUBIC)
            im_b = im_b.resize((height,width), resample = Image.BICUBIC)
            im_b2 = pil_disk_blur(im_gt,scale*2)
            
            im_h, psnr_bicubic, psnr_predicted = display_PSNR(im_gt, im_b, im_b2, model, channels=channels, display = display)
            psnr_bicubic_sum = psnr_bicubic_sum + psnr_bicubic
            psnr_model_sum = psnr_model_sum + psnr_predicted
            ct = ct +1
            #item = {"Filepath":filepath, "Type":"image"}
            #instances.append(item)
        
    psnr_bicubic_avg = psnr_bicubic_sum / ct
    psnr_model_avg = psnr_model_sum / ct
        
    print("Bicubic average PSNR =",psnr_bicubic_avg)
    print("Model average PSNR =",psnr_model_avg)
    return

# %%
test_results("/media/SSD/superres/video_data/test_data/Set5", 3, channels = 1,display = True)

# %%
test_results("/media/SSD/superres/video_data/test_data/Set5", 4, channels = 1,display = True)

# %% [markdown]
# # convert sample videos

# %%
result_path

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-16.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=1.6,display=False,bitrate= "4000k")

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-10.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=False,bitrate= "4000k")

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-20.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=2.0,display=False,bitrate= "4000k")

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-30.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=3.0,display=False,bitrate= "4000k")

# %%
dualfile= str(result_path/"muffins30sec-30dual.mp4")
infile = str(infile)
outfile = str(outfile)

# %%
# double scale for video x3 2 min
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -t 120 -filter_complex "[0:v] scale=iw*2:ih*2, pad=2*iw:ih [left]; [1:v] scale=iw/1.5:ih/1.5 [right]; [left][right] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
# original scale , for video x3
#!ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v] scale=iw*1:ih*1, pad=2*iw:ih [left]; [1:v] scale=iw/3:ih/3 [right]; [left][right] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
infile = "/media/SSD/superres/super8/super8_best_from_mp2.mp4"
outfile = result_path/"super8.mp4"
error_file = "/media/SSD/superres/error.txt"
superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=False,bitrate= "4000k",errorfile = error_file)

# %%
dualfile = str(result_path/"super8dual.mp4")
infile = str(infile)
outfile = str(outfile)

# %%
# original scale , for film x1, removed un needed scaling
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v]  pad=2*iw:ih [left];  [left][1:v] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
# compare this model to the last one
infile = "/media/SSD/superres/Results/Superresolution train vdsr with hres perception loss multifuz/super8hresperfuzmodel2.mp4"
outfile = str(result_path/"super8.mp4")
dualfile= str(result_path/"super8-tolast-dual.mp4")

# %%
# original scale , for film x1, removed un needed scaling
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v]  pad=2*iw:ih [left];  [left][1:v] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
infile = "/media/SSD/superres/super8/Old 8mm Reels_1.mp4"
outfile = str(result_path/"super8long.mp4")
error_file = "/media/SSD/superres/error.txt"
superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=False,bitrate= "4000k",errorfile = error_file)

# %%
dualfile= str(result_path/"super8longdual.mp4")
infile = str(infile)
outfile = str(outfile)

# %%
# original scale , for film x1, removed un needed scaling
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v]  pad=2*iw:ih [left];  [left][1:v] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}
