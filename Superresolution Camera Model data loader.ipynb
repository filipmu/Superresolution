# %% [markdown]
# # Apply AI Superresolution to video - make the camera model version of the data loader
#
# * Data loader returns high res target image and a parameter list defining a fuzification (camera model).
# * The camera model is selected at random based on defined distributions.
#
# * allows easier definition of training and test sets
# * allows reuse of camera model in training (to invert the output of the model, for example)
# * model can be trained on camera model parameters

# %% [markdown]
# # Project Documentation

# %%
from pathlib import Path
import os


project_base = "/media/SSD/superres/"
results_folder = "Results"
data_folder = "video_data"
model_folder = "checkpoint"

model_name_base = "TEST"

# %% [markdown]
# ## Experiment documentation

# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
print("NOTEBOOK_FULL_PATH:\n", NOTEBOOK_FULL_PATH)
# Out:
# NOTEBOOK_FULL_PATH:
#  /SSD_link/superres/Superresolution Camera Model data loader.ipynb

# %%
nb_path = Path(NOTEBOOK_FULL_PATH)
print(nb_path)

# Make result folder if it does not exist
result_path = Path(project_base, results_folder , nb_path.stem )
print(result_path)
os.makedirs(result_path, exist_ok=True)
# Out:
# /SSD_link/superres/Superresolution Camera Model data loader.ipynb
# /media/SSD/superres/Results/Superresolution Camera Model data loader

# %%
model_out_path=Path(project_base)/model_folder
print(model_out_path)
os.makedirs(model_out_path, exist_ok=True)
# Out:
# /media/SSD/superres/checkpoint

# %%
# Tie a result to a set of params.  Tie a set of params to a model.  Tie a model to a notebook.
# register the experiment to get a unique run id
# save all the results in a repository
# use github to do it?

# %%
#%reload_ext autoreload
#%autoreload 2
#%matplotlib inline


import cv2 
import numpy as np
import subprocess as sp
import time
from tqdm import tqdm, trange
import torch
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from torchvision.transforms import RandomHorizontalFlip,ColorJitter
from torchvision.transforms import Compose, CenterCrop, ToTensor, Resize, Grayscale,ToPILImage

import random
#from astropy.convolution import  Gaussian2DKernel, Tophat2DKernel,AiryDisk2DKernel


#import sys
#sys.path.insert(0, '/media/SSD/superres/pytorch-vdsr/')

#from vdsr import Net

#import lpips #https://github.com/richzhang/PerceptualSimilarity

# %%
import torch.utils.data as data

from os import listdir
from os.path import join
from PIL import Image, ImageFilter
import numpy as np
import torchvision as vision

import numbers


torch.cuda.manual_seed(42)

# %% [markdown]
# Create a data loader
# - see https://github.com/2KangHo/vdsr_pytorch/blob/master/data.py
# - see https://github.com/2KangHo/vdsr_pytorch/blob/master/data_utils.py

# %%
toPIL = vision.transforms.ToPILImage()


def noisy(img, std=3.0):
    mean = 0.0
    gauss = np.random.normal(mean, std, (img.height, img.width, 3))
    # noisy = np.clip(np.uint8(img + gauss), 0, 255)
    noisy = np.uint8(img + gauss)
    return noisy


def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg", ".bmp"])

# %%
def is_video_file(path, extensions = ("mp4",)):
    return path.lower().endswith(extensions)

def frame_sampler1(length, frame_sample_size):

    # calculate middle of video and take 'frame_sample_size' frames from middle
    middle = length // 2
    left_length = frame_sample_size//2
    right_length = frame_sample_size - left_length
    left = max(0,middle - left_length)
    right = min(length, middle + right_length)
          
    return list(range(left,right))



def frame_sampler2(length, frame_sample_size):
    return np.linspace(0, length, 3+min(frame_sample_size,length)).astype(int)[2:-1]


# Make this load still photos too, and have them added with frame = 0
def make_framelist(video_dir,frame_sample_size = 10):
    instances = []
    for filename in listdir(video_dir):
        filepath = os.path.join(video_dir,filename)
        #print(filename)
        
        if is_video_file(filepath):
            # open video file
            cap = cv2.VideoCapture(str(filepath))

            # get frame count
            length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            cap.release()
            
            if frame_sample_size is not None:
                samples = frame_sampler2(length, frame_sample_size)
                # append fn and frame num to instances
            else:
                samples = range(0,length)
                
            for frame in samples:
                item = {"Filepath":filepath,"Type":"frame",  "Framenum":frame}
                instances.append(item)
                
        elif is_image_file(filepath):
            # open image file
            img = cv2.imread(filepath)
            item = {"Filepath":filepath, "Type":"image"}
            instances.append(item)
            
    return instances

# %%
# get a list of all the data
instances = make_framelist("/media/SSD/superres/video_data/train_data",1)

# %%
instances
# Out:
# [{'Filepath': '/media/SSD/superres/video_data/train_data/101890319.mp4',
#   'Type': 'frame',
#   'Framenum': 3431},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107132164.mp4',
#   'Type': 'frame',
#   'Framenum': 1634},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104453980.mp4',
#   'Type': 'frame',
#   'Framenum': 15060},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103604430.mp4',
#   'Type': 'frame',
#   'Framenum': 5538},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110371795.mp4',
#   'Type': 'frame',
#   'Framenum': 744},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101224055.mp4',
#   'Type': 'frame',
#   'Framenum': 3954},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101094248.mp4',
#   'Type': 'frame',
#   'Framenum': 3290},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106501635.mp4',
#   'Type': 'frame',
#   'Framenum': 1580},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102797996.mp4',
#   'Type': 'frame',
#   'Framenum': 542},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114651311.mp4',
#   'Type': 'frame',
#   'Framenum': 3020},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112832256.mp4',
#   'Type': 'frame',
#   'Framenum': 966},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104820561.mp4',
#   'Type': 'frame',
#   'Framenum': 2434},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115542613.mp4',
#   'Type': 'frame',
#   'Framenum': 2740},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114419059.mp4',
#   'Type': 'frame',
#   'Framenum': 1210},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115542615.mp4',
#   'Type': 'frame',
#   'Framenum': 2833},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108973836.mp4',
#   'Type': 'frame',
#   'Framenum': 686},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113921301.mp4',
#   'Type': 'frame',
#   'Framenum': 6098},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106678333.mp4',
#   'Type': 'frame',
#   'Framenum': 178},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108620147.mp4',
#   'Type': 'frame',
#   'Framenum': 2354},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/DSC00862.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111170153.mp4',
#   'Type': 'frame',
#   'Framenum': 4610},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114585686.mp4',
#   'Type': 'frame',
#   'Framenum': 2362},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106308150.mp4',
#   'Type': 'frame',
#   'Framenum': 1094},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108305495.mp4',
#   'Type': 'frame',
#   'Framenum': 1008},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111655102.mp4',
#   'Type': 'frame',
#   'Framenum': 5626},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100364573.mp4',
#   'Type': 'frame',
#   'Framenum': 487},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111436036.mp4',
#   'Type': 'frame',
#   'Framenum': 333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114571839.mp4',
#   'Type': 'frame',
#   'Framenum': 393},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103312959.mp4',
#   'Type': 'frame',
#   'Framenum': 500},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115807414.mp4',
#   'Type': 'frame',
#   'Framenum': 254},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111415843.mp4',
#   'Type': 'frame',
#   'Framenum': 972},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/DSC00515.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110371793.mp4',
#   'Type': 'frame',
#   'Framenum': 1454},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106021559.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100014835.mp4',
#   'Type': 'frame',
#   'Framenum': 238},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100640779.mp4',
#   'Type': 'frame',
#   'Framenum': 552},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100117753.mp4',
#   'Type': 'frame',
#   'Framenum': 3100},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111201787.mp4',
#   'Type': 'frame',
#   'Framenum': 612},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107514013.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104163230.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110536371.mp4',
#   'Type': 'frame',
#   'Framenum': 8342},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/178858950.mp4',
#   'Type': 'frame',
#   'Framenum': 9732},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110508165.mp4',
#   'Type': 'frame',
#   'Framenum': 3104},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115807418.mp4',
#   'Type': 'frame',
#   'Framenum': 362},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115806850.mp4',
#   'Type': 'frame',
#   'Framenum': 238},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/292184739.mp4',
#   'Type': 'frame',
#   'Framenum': 1656},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114768665.mp4',
#   'Type': 'frame',
#   'Framenum': 1612},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110368176.mp4',
#   'Type': 'frame',
#   'Framenum': 6523},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108285702.mp4',
#   'Type': 'frame',
#   'Framenum': 333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115028946.mp4',
#   'Type': 'frame',
#   'Framenum': 1841},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100804176.mp4',
#   'Type': 'frame',
#   'Framenum': 9626},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108017254.mp4',
#   'Type': 'frame',
#   'Framenum': 490},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/10051035.mp4',
#   'Type': 'frame',
#   'Framenum': 870},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112197207.mp4',
#   'Type': 'frame',
#   'Framenum': 1288},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114566242.mp4',
#   'Type': 'frame',
#   'Framenum': 239},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100912125.mp4',
#   'Type': 'frame',
#   'Framenum': 500},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115285056.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105773483.mp4',
#   'Type': 'frame',
#   'Framenum': 925},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114566241.mp4',
#   'Type': 'frame',
#   'Framenum': 392},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109414623.mp4',
#   'Type': 'frame',
#   'Framenum': 2678},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104338421.mp4',
#   'Type': 'frame',
#   'Framenum': 300},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114292197.mp4',
#   'Type': 'frame',
#   'Framenum': 1494},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103615402.mp4',
#   'Type': 'frame',
#   'Framenum': 1432},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104059123.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112527024.mp4',
#   'Type': 'frame',
#   'Framenum': 2268},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112184926.mp4',
#   'Type': 'frame',
#   'Framenum': 2872},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108921230.mp4',
#   'Type': 'frame',
#   'Framenum': 904},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114571838.mp4',
#   'Type': 'frame',
#   'Framenum': 425},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/10450125.mp4',
#   'Type': 'frame',
#   'Framenum': 2485},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112217883.mp4',
#   'Type': 'frame',
#   'Framenum': 14561},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115950663.mp4',
#   'Type': 'frame',
#   'Framenum': 516},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114673224.mp4',
#   'Type': 'frame',
#   'Framenum': 5422},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108941856.mp4',
#   'Type': 'frame',
#   'Framenum': 960},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110510735.mp4',
#   'Type': 'frame',
#   'Framenum': 3558},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108848234.mp4',
#   'Type': 'frame',
#   'Framenum': 632},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108284456.mp4',
#   'Type': 'frame',
#   'Framenum': 333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104592342.mp4',
#   'Type': 'frame',
#   'Framenum': 584},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111614300.mp4',
#   'Type': 'frame',
#   'Framenum': 335},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106943393.mp4',
#   'Type': 'frame',
#   'Framenum': 906},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112577467.mp4',
#   'Type': 'frame',
#   'Framenum': 1500},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106940165.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113296466.mp4',
#   'Type': 'frame',
#   'Framenum': 2124},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103879054.mp4',
#   'Type': 'frame',
#   'Framenum': 5100},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103001252.mp4',
#   'Type': 'frame',
#   'Framenum': 1500},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109325843.mp4',
#   'Type': 'frame',
#   'Framenum': 756},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104059122.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107002180.mp4',
#   'Type': 'frame',
#   'Framenum': 646},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115806849.mp4',
#   'Type': 'frame',
#   'Framenum': 263},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100002397.mp4',
#   'Type': 'frame',
#   'Framenum': 1228},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115212728.mp4',
#   'Type': 'frame',
#   'Framenum': 2658},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102666136.mp4',
#   'Type': 'frame',
#   'Framenum': 1504},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101559417.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102776436.mp4',
#   'Type': 'frame',
#   'Framenum': 1200},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110103142.mp4',
#   'Type': 'frame',
#   'Framenum': 445},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101665319.mp4',
#   'Type': 'frame',
#   'Framenum': 208},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115590868.mp4',
#   'Type': 'frame',
#   'Framenum': 354},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102734274.mp4',
#   'Type': 'frame',
#   'Framenum': 4436},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109606929.mp4',
#   'Type': 'frame',
#   'Framenum': 1616},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104415044.mp4',
#   'Type': 'frame',
#   'Framenum': 2757},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102354539.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/dad barbequeing_0012.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114529064.mp4',
#   'Type': 'frame',
#   'Framenum': 2811},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115310219.mp4',
#   'Type': 'frame',
#   'Framenum': 2141},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100299381.mp4',
#   'Type': 'frame',
#   'Framenum': 1406},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115436421.mp4',
#   'Type': 'frame',
#   'Framenum': 202},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107540226.mp4',
#   'Type': 'frame',
#   'Framenum': 1969},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114381017.mp4',
#   'Type': 'frame',
#   'Framenum': 1624},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109903497.mp4',
#   'Type': 'frame',
#   'Framenum': 698},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102797997.mp4',
#   'Type': 'frame',
#   'Framenum': 499},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115644206.mp4',
#   'Type': 'frame',
#   'Framenum': 867},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111463084.mp4',
#   'Type': 'frame',
#   'Framenum': 440},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105495431.mp4',
#   'Type': 'frame',
#   'Framenum': 1486},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113886553.mp4',
#   'Type': 'frame',
#   'Framenum': 4984},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115782500.mp4',
#   'Type': 'frame',
#   'Framenum': 6489},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110481444.mp4',
#   'Type': 'frame',
#   'Framenum': 2569},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100199211.mp4',
#   'Type': 'frame',
#   'Framenum': 1283},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115651857.mp4',
#   'Type': 'frame',
#   'Framenum': 3898},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116029999.mp4',
#   'Type': 'frame',
#   'Framenum': 3205},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114682400.mp4',
#   'Type': 'frame',
#   'Framenum': 1708},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100791452.mp4',
#   'Type': 'frame',
#   'Framenum': 666},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109290315.mp4',
#   'Type': 'frame',
#   'Framenum': 2219},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109203805.mp4',
#   'Type': 'frame',
#   'Framenum': 901},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102646150.mp4',
#   'Type': 'frame',
#   'Framenum': 1987},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113399966.mp4',
#   'Type': 'frame',
#   'Framenum': 2187},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107498144.mp4',
#   'Type': 'frame',
#   'Framenum': 600},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108053031.mp4',
#   'Type': 'frame',
#   'Framenum': 590},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100642275.mp4',
#   'Type': 'frame',
#   'Framenum': 4182},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100131372.mp4',
#   'Type': 'frame',
#   'Framenum': 400},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114639511.mp4',
#   'Type': 'frame',
#   'Framenum': 3096},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108122652.mp4',
#   'Type': 'frame',
#   'Framenum': 3282},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116297095.mp4',
#   'Type': 'frame',
#   'Framenum': 766},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111798738.mp4',
#   'Type': 'frame',
#   'Framenum': 13223},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115193053.mp4',
#   'Type': 'frame',
#   'Framenum': 202},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115874792.mp4',
#   'Type': 'frame',
#   'Framenum': 2108},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103305603.mp4',
#   'Type': 'frame',
#   'Framenum': 871},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110764182.mp4',
#   'Type': 'frame',
#   'Framenum': 7938},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114607001.mp4',
#   'Type': 'frame',
#   'Framenum': 518},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113755247.mp4',
#   'Type': 'frame',
#   'Framenum': 485},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105773482.mp4',
#   'Type': 'frame',
#   'Framenum': 811},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114354905.mp4',
#   'Type': 'frame',
#   'Framenum': 13918},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115897029.mp4',
#   'Type': 'frame',
#   'Framenum': 1426},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102526672.mp4',
#   'Type': 'frame',
#   'Framenum': 1161},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115806853.mp4',
#   'Type': 'frame',
#   'Framenum': 253},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116030001.mp4',
#   'Type': 'frame',
#   'Framenum': 2197},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103757754.mp4',
#   'Type': 'frame',
#   'Framenum': 2706},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103425690.mp4',
#   'Type': 'frame',
#   'Framenum': 4574},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106870767.mp4',
#   'Type': 'frame',
#   'Framenum': 3892},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100804175.mp4',
#   'Type': 'frame',
#   'Framenum': 750},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108036387.mp4',
#   'Type': 'frame',
#   'Framenum': 240},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102568206.mp4',
#   'Type': 'frame',
#   'Framenum': 3028},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101310160.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110511439.mp4',
#   'Type': 'frame',
#   'Framenum': 1538},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108689045.mp4',
#   'Type': 'frame',
#   'Framenum': 1492},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106986183.mp4',
#   'Type': 'frame',
#   'Framenum': 498},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111055424.mp4',
#   'Type': 'frame',
#   'Framenum': 3204},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115652407.mp4',
#   'Type': 'frame',
#   'Framenum': 1680},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103976113.mp4',
#   'Type': 'frame',
#   'Framenum': 1110},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112501784.mp4',
#   'Type': 'frame',
#   'Framenum': 1912},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100906353.mp4',
#   'Type': 'frame',
#   'Framenum': 1491},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106943958.mp4',
#   'Type': 'frame',
#   'Framenum': 6173},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110533983.mp4',
#   'Type': 'frame',
#   'Framenum': 3368},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112086670.mp4',
#   'Type': 'frame',
#   'Framenum': 3261},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/dad barbequeing_0003.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104999400.mp4',
#   'Type': 'frame',
#   'Framenum': 484},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115869835.mp4',
#   'Type': 'frame',
#   'Framenum': 1000},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111674886.mp4',
#   'Type': 'frame',
#   'Framenum': 5543},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111298082.mp4',
#   'Type': 'frame',
#   'Framenum': 1920},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108131371.mp4',
#   'Type': 'frame',
#   'Framenum': 8511},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100626145.mp4',
#   'Type': 'frame',
#   'Framenum': 2758},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108292572.mp4',
#   'Type': 'frame',
#   'Framenum': 528},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103236157.mp4',
#   'Type': 'frame',
#   'Framenum': 3019},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110705405.mp4',
#   'Type': 'frame',
#   'Framenum': 363},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115436423.mp4',
#   'Type': 'frame',
#   'Framenum': 386},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116327575.mp4',
#   'Type': 'frame',
#   'Framenum': 500},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113652747.mp4',
#   'Type': 'frame',
#   'Framenum': 496},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115788065.mp4',
#   'Type': 'frame',
#   'Framenum': 1170},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108177288.mp4',
#   'Type': 'frame',
#   'Framenum': 978},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101330695.mp4',
#   'Type': 'frame',
#   'Framenum': 1948},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102598844.mp4',
#   'Type': 'frame',
#   'Framenum': 4983},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102790728.mp4',
#   'Type': 'frame',
#   'Framenum': 966},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103285867.mp4',
#   'Type': 'frame',
#   'Framenum': 895},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107925972.mp4',
#   'Type': 'frame',
#   'Framenum': 2212},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112233733.mp4',
#   'Type': 'frame',
#   'Framenum': 2793},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102797995.mp4',
#   'Type': 'frame',
#   'Framenum': 535},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111504000.mp4',
#   'Type': 'frame',
#   'Framenum': 4698},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107417811.mp4',
#   'Type': 'frame',
#   'Framenum': 2945},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101136413.mp4',
#   'Type': 'frame',
#   'Framenum': 890},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104183691.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116004273.mp4',
#   'Type': 'frame',
#   'Framenum': 970},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114402319.mp4',
#   'Type': 'frame',
#   'Framenum': 4458},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111734118.mp4',
#   'Type': 'frame',
#   'Framenum': 533},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107957884.mp4',
#   'Type': 'frame',
#   'Framenum': 258},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102832433.mp4',
#   'Type': 'frame',
#   'Framenum': 1692},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111017740.mp4',
#   'Type': 'frame',
#   'Framenum': 1376},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100733142.mp4',
#   'Type': 'frame',
#   'Framenum': 4967},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115437593.mp4',
#   'Type': 'frame',
#   'Framenum': 263},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052311.mp4',
#   'Type': 'frame',
#   'Framenum': 1663},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108486311.mp4',
#   'Type': 'frame',
#   'Framenum': 1290},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102634902.mp4',
#   'Type': 'frame',
#   'Framenum': 5178},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108375943.mp4',
#   'Type': 'frame',
#   'Framenum': 333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112077975.mp4',
#   'Type': 'frame',
#   'Framenum': 2142},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101909728.mp4',
#   'Type': 'frame',
#   'Framenum': 1555},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102528627.mp4',
#   'Type': 'frame',
#   'Framenum': 6589},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106806817.mp4',
#   'Type': 'frame',
#   'Framenum': 584},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110212454.mp4',
#   'Type': 'frame',
#   'Framenum': 4059},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114271912.mp4',
#   'Type': 'frame',
#   'Framenum': 740},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116089900.mp4',
#   'Type': 'frame',
#   'Framenum': 2015},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/P1030294.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/55172677.mp4',
#   'Type': 'frame',
#   'Framenum': 319},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115294214.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100002264.mp4',
#   'Type': 'frame',
#   'Framenum': 1180},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106908866.mp4',
#   'Type': 'frame',
#   'Framenum': 1024},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110864795.mp4',
#   'Type': 'frame',
#   'Framenum': 277},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115885790.mp4',
#   'Type': 'frame',
#   'Framenum': 5574},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105329527.mp4',
#   'Type': 'frame',
#   'Framenum': 108},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116030000.mp4',
#   'Type': 'frame',
#   'Framenum': 1699},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104656813.mp4',
#   'Type': 'frame',
#   'Framenum': 2139},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113295059.mp4',
#   'Type': 'frame',
#   'Framenum': 600},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115649908.mp4',
#   'Type': 'frame',
#   'Framenum': 3571},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112228850.mp4',
#   'Type': 'frame',
#   'Framenum': 3165},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114571837.mp4',
#   'Type': 'frame',
#   'Framenum': 197},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112110402.mp4',
#   'Type': 'frame',
#   'Framenum': 1678},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107002179.mp4',
#   'Type': 'frame',
#   'Framenum': 502},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111514047.mp4',
#   'Type': 'frame',
#   'Framenum': 1174},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100520487.mp4',
#   'Type': 'frame',
#   'Framenum': 3040},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100483730.mp4',
#   'Type': 'frame',
#   'Framenum': 1120},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112662938.mp4',
#   'Type': 'frame',
#   'Framenum': 3976},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104425894.mp4',
#   'Type': 'frame',
#   'Framenum': 880},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052307.mp4',
#   'Type': 'frame',
#   'Framenum': 840},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101111032.mp4',
#   'Type': 'frame',
#   'Framenum': 960},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115193056.mp4',
#   'Type': 'frame',
#   'Framenum': 422},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104716725.mp4',
#   'Type': 'frame',
#   'Framenum': 4074},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114028363.mp4',
#   'Type': 'frame',
#   'Framenum': 3435},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103167342.mp4',
#   'Type': 'frame',
#   'Framenum': 1842},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103138762.mp4',
#   'Type': 'frame',
#   'Framenum': 1735},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103305190.mp4',
#   'Type': 'frame',
#   'Framenum': 998},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106308151.mp4',
#   'Type': 'frame',
#   'Framenum': 808},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109186707.mp4',
#   'Type': 'frame',
#   'Framenum': 478},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108626165.mp4',
#   'Type': 'frame',
#   'Framenum': 1445},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106638858.mp4',
#   'Type': 'frame',
#   'Framenum': 2626},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106178476.mp4',
#   'Type': 'frame',
#   'Framenum': 501},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102776435.mp4',
#   'Type': 'frame',
#   'Framenum': 870},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111466492.mp4',
#   'Type': 'frame',
#   'Framenum': 602},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112371113.mp4',
#   'Type': 'frame',
#   'Framenum': 1318},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108092429.mp4',
#   'Type': 'frame',
#   'Framenum': 2284},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114023146.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115085483.mp4',
#   'Type': 'frame',
#   'Framenum': 1400},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104628157.mp4',
#   'Type': 'frame',
#   'Framenum': 1862},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114328732.mp4',
#   'Type': 'frame',
#   'Framenum': 1007},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114571844.mp4',
#   'Type': 'frame',
#   'Framenum': 217},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112613369.mp4',
#   'Type': 'frame',
#   'Framenum': 1115},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113040345.mp4',
#   'Type': 'frame',
#   'Framenum': 2944},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110864797.mp4',
#   'Type': 'frame',
#   'Framenum': 452},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100562177.mp4',
#   'Type': 'frame',
#   'Framenum': 523},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115808467.mp4',
#   'Type': 'frame',
#   'Framenum': 278},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107592567.mp4',
#   'Type': 'frame',
#   'Framenum': 1148},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103278642.mp4',
#   'Type': 'frame',
#   'Framenum': 762},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109127209.mp4',
#   'Type': 'frame',
#   'Framenum': 888},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115942083.mp4',
#   'Type': 'frame',
#   'Framenum': 3320},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103243457.mp4',
#   'Type': 'frame',
#   'Framenum': 1222},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114865390.mp4',
#   'Type': 'frame',
#   'Framenum': 417},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106308149.mp4',
#   'Type': 'frame',
#   'Framenum': 1008},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110678266.mp4',
#   'Type': 'frame',
#   'Framenum': 4692},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114569564.mp4',
#   'Type': 'frame',
#   'Framenum': 356},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115437595.mp4',
#   'Type': 'frame',
#   'Framenum': 237},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110864799.mp4',
#   'Type': 'frame',
#   'Framenum': 196},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111514046.mp4',
#   'Type': 'frame',
#   'Framenum': 1262},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114658705.mp4',
#   'Type': 'frame',
#   'Framenum': 1396},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115153372.mp4',
#   'Type': 'frame',
#   'Framenum': 856},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116129155.mp4',
#   'Type': 'frame',
#   'Framenum': 5727},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115175810.mp4',
#   'Type': 'frame',
#   'Framenum': 1704},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104786087.mp4',
#   'Type': 'frame',
#   'Framenum': 3052},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115808083.mp4',
#   'Type': 'frame',
#   'Framenum': 435},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111947770.mp4',
#   'Type': 'frame',
#   'Framenum': 629},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114454903.mp4',
#   'Type': 'frame',
#   'Framenum': 2606},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110918461.mp4',
#   'Type': 'frame',
#   'Framenum': 3823},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112508074.mp4',
#   'Type': 'frame',
#   'Framenum': 200},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100512588.mp4',
#   'Type': 'frame',
#   'Framenum': 3830},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105901680.mp4',
#   'Type': 'frame',
#   'Framenum': 3298},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108994100.mp4',
#   'Type': 'frame',
#   'Framenum': 810},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116325824.mp4',
#   'Type': 'frame',
#   'Framenum': 4400},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107002177.mp4',
#   'Type': 'frame',
#   'Framenum': 490},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111594944.mp4',
#   'Type': 'frame',
#   'Framenum': 1047},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106986182.mp4',
#   'Type': 'frame',
#   'Framenum': 1046},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111205107.mp4',
#   'Type': 'frame',
#   'Framenum': 320},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108865843.mp4',
#   'Type': 'frame',
#   'Framenum': 6020},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/dad barbequeing_0002.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107224001.mp4',
#   'Type': 'frame',
#   'Framenum': 5704},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100742368.mp4',
#   'Type': 'frame',
#   'Framenum': 1482},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103811690.mp4',
#   'Type': 'frame',
#   'Framenum': 600},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/dad barbequeing_0005.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110388311.mp4',
#   'Type': 'frame',
#   'Framenum': 1893},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109800722.mp4',
#   'Type': 'frame',
#   'Framenum': 2171},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108426265.mp4',
#   'Type': 'frame',
#   'Framenum': 1411},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104103094.mp4',
#   'Type': 'frame',
#   'Framenum': 906},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114380140.mp4',
#   'Type': 'frame',
#   'Framenum': 1020},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108292575.mp4',
#   'Type': 'frame',
#   'Framenum': 1008},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052310.mp4',
#   'Type': 'frame',
#   'Framenum': 860},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113059864.mp4',
#   'Type': 'frame',
#   'Framenum': 1670},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115808468.mp4',
#   'Type': 'frame',
#   'Framenum': 729},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106986181.mp4',
#   'Type': 'frame',
#   'Framenum': 3328},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100626144.mp4',
#   'Type': 'frame',
#   'Framenum': 2825},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107004588.mp4',
#   'Type': 'frame',
#   'Framenum': 525},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103970529.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100923370.mp4',
#   'Type': 'frame',
#   'Framenum': 979},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114375619.mp4',
#   'Type': 'frame',
#   'Framenum': 740},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115807889.mp4',
#   'Type': 'frame',
#   'Framenum': 1681},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108620149.mp4',
#   'Type': 'frame',
#   'Framenum': 482},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101724557.mp4',
#   'Type': 'frame',
#   'Framenum': 240},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/10052029.mp4',
#   'Type': 'frame',
#   'Framenum': 1170},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106566080.mp4',
#   'Type': 'frame',
#   'Framenum': 2398},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107655563.mp4',
#   'Type': 'frame',
#   'Framenum': 493},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108173868.mp4',
#   'Type': 'frame',
#   'Framenum': 3564},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104517973.mp4',
#   'Type': 'frame',
#   'Framenum': 2430},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106221690.mp4',
#   'Type': 'frame',
#   'Framenum': 340},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114225291.mp4',
#   'Type': 'frame',
#   'Framenum': 1009},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113972128.mp4',
#   'Type': 'frame',
#   'Framenum': 2348},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113028469.mp4',
#   'Type': 'frame',
#   'Framenum': 968},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113507330.mp4',
#   'Type': 'frame',
#   'Framenum': 1033},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112004933.mp4',
#   'Type': 'frame',
#   'Framenum': 2420},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115225919.mp4',
#   'Type': 'frame',
#   'Framenum': 2230},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052981.mp4',
#   'Type': 'frame',
#   'Framenum': 508},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107081899.mp4',
#   'Type': 'frame',
#   'Framenum': 2672},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107525843.mp4',
#   'Type': 'frame',
#   'Framenum': 3824},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114787400.mp4',
#   'Type': 'frame',
#   'Framenum': 2240},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112868738.mp4',
#   'Type': 'frame',
#   'Framenum': 1790},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100153779.mp4',
#   'Type': 'frame',
#   'Framenum': 1656},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115436422.mp4',
#   'Type': 'frame',
#   'Framenum': 351},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101630714.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107868459.mp4',
#   'Type': 'frame',
#   'Framenum': 600},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113412894.mp4',
#   'Type': 'frame',
#   'Framenum': 4615},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108947784.mp4',
#   'Type': 'frame',
#   'Framenum': 1161},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100364843.mp4',
#   'Type': 'frame',
#   'Framenum': 599},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102511293.mp4',
#   'Type': 'frame',
#   'Framenum': 2045},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106549724.mp4',
#   'Type': 'frame',
#   'Framenum': 1006},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108775709.mp4',
#   'Type': 'frame',
#   'Framenum': 2247},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101107614.mp4',
#   'Type': 'frame',
#   'Framenum': 620},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102042507.mp4',
#   'Type': 'frame',
#   'Framenum': 1333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112897407.mp4',
#   'Type': 'frame',
#   'Framenum': 1954},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/dad barbequeing_0016.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103928951.mp4',
#   'Type': 'frame',
#   'Framenum': 568},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111138433.mp4',
#   'Type': 'frame',
#   'Framenum': 395},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112356712.mp4',
#   'Type': 'frame',
#   'Framenum': 3711},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105773481.mp4',
#   'Type': 'frame',
#   'Framenum': 4442},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102353531.mp4',
#   'Type': 'frame',
#   'Framenum': 1805},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/17851496.mp4',
#   'Type': 'frame',
#   'Framenum': 2805},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109359930.mp4',
#   'Type': 'frame',
#   'Framenum': 1118},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112268851.mp4',
#   'Type': 'frame',
#   'Framenum': 334},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115836708.mp4',
#   'Type': 'frame',
#   'Framenum': 2232},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101954544.mp4',
#   'Type': 'frame',
#   'Framenum': 866},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114570696.mp4',
#   'Type': 'frame',
#   'Framenum': 228},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115807422.mp4',
#   'Type': 'frame',
#   'Framenum': 402},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115509809.mp4',
#   'Type': 'frame',
#   'Framenum': 13068},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115156856.mp4',
#   'Type': 'frame',
#   'Framenum': 642},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108282986.mp4',
#   'Type': 'frame',
#   'Framenum': 333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109058390.mp4',
#   'Type': 'frame',
#   'Framenum': 5701},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105959183.mp4',
#   'Type': 'frame',
#   'Framenum': 1288},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115436420.mp4',
#   'Type': 'frame',
#   'Framenum': 358},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111863405.mp4',
#   'Type': 'frame',
#   'Framenum': 889},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100649167.mp4',
#   'Type': 'frame',
#   'Framenum': 1725},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113011238.mp4',
#   'Type': 'frame',
#   'Framenum': 1037},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115950982.mp4',
#   'Type': 'frame',
#   'Framenum': 2008},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115806852.mp4',
#   'Type': 'frame',
#   'Framenum': 368},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107873432.mp4',
#   'Type': 'frame',
#   'Framenum': 515},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109550271.mp4',
#   'Type': 'frame',
#   'Framenum': 4140},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108292570.mp4',
#   'Type': 'frame',
#   'Framenum': 528},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105773486.mp4',
#   'Type': 'frame',
#   'Framenum': 3162},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/68445748.mp4',
#   'Type': 'frame',
#   'Framenum': 1973},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101301088.mp4',
#   'Type': 'frame',
#   'Framenum': 240},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105728658.mp4',
#   'Type': 'frame',
#   'Framenum': 714},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101256216.mp4',
#   'Type': 'frame',
#   'Framenum': 565},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106966649.mp4',
#   'Type': 'frame',
#   'Framenum': 4764},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112612299.mp4',
#   'Type': 'frame',
#   'Framenum': 937},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114719639.mp4',
#   'Type': 'frame',
#   'Framenum': 1679},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/89190137.mp4',
#   'Type': 'frame',
#   'Framenum': 3270},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052987.mp4',
#   'Type': 'frame',
#   'Framenum': 610},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/DSC00478.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115959032.mp4',
#   'Type': 'frame',
#   'Framenum': 1086},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105946067.mp4',
#   'Type': 'frame',
#   'Framenum': 466},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110543721.mp4',
#   'Type': 'frame',
#   'Framenum': 4536},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112047457.mp4',
#   'Type': 'frame',
#   'Framenum': 2823},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114439551.mp4',
#   'Type': 'frame',
#   'Framenum': 2611},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104498702.mp4',
#   'Type': 'frame',
#   'Framenum': 1200},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113443764.mp4',
#   'Type': 'frame',
#   'Framenum': 1734},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102144809.mp4',
#   'Type': 'frame',
#   'Framenum': 1503},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114272181.mp4',
#   'Type': 'frame',
#   'Framenum': 740},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106678331.mp4',
#   'Type': 'frame',
#   'Framenum': 418},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107636899.mp4',
#   'Type': 'frame',
#   'Framenum': 959},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108137271.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102776434.mp4',
#   'Type': 'frame',
#   'Framenum': 4010},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114569565.mp4',
#   'Type': 'frame',
#   'Framenum': 375},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104714251.mp4',
#   'Type': 'frame',
#   'Framenum': 901},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110560915.mp4',
#   'Type': 'frame',
#   'Framenum': 1190},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111983263.mp4',
#   'Type': 'frame',
#   'Framenum': 6308},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109229702.mp4',
#   'Type': 'frame',
#   'Framenum': 1622},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111723857.mp4',
#   'Type': 'frame',
#   'Framenum': 695},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108017253.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100923372.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100876771.mp4',
#   'Type': 'frame',
#   'Framenum': 960},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103619946.mp4',
#   'Type': 'frame',
#   'Framenum': 4778},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100876773.mp4',
#   'Type': 'frame',
#   'Framenum': 3732},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111514862.mp4',
#   'Type': 'frame',
#   'Framenum': 1358},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052304.mp4',
#   'Type': 'frame',
#   'Framenum': 1174},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108204139.mp4',
#   'Type': 'frame',
#   'Framenum': 8726},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106783237.mp4',
#   'Type': 'frame',
#   'Framenum': 515},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107002176.mp4',
#   'Type': 'frame',
#   'Framenum': 483},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113362753.mp4',
#   'Type': 'frame',
#   'Framenum': 3491},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107280403.mp4',
#   'Type': 'frame',
#   'Framenum': 1848},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105787788.mp4',
#   'Type': 'frame',
#   'Framenum': 961},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102227637.mp4',
#   'Type': 'frame',
#   'Framenum': 814},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115961480.mp4',
#   'Type': 'frame',
#   'Framenum': 3916},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100924100.mp4',
#   'Type': 'frame',
#   'Framenum': 2095},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111023781.mp4',
#   'Type': 'frame',
#   'Framenum': 2232},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105052720.mp4',
#   'Type': 'frame',
#   'Framenum': 1258},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103001250.mp4',
#   'Type': 'frame',
#   'Framenum': 500},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114663579.mp4',
#   'Type': 'frame',
#   'Framenum': 2562},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104373280.mp4',
#   'Type': 'frame',
#   'Framenum': 758},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104254302.mp4',
#   'Type': 'frame',
#   'Framenum': 1803},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111849522.mp4',
#   'Type': 'frame',
#   'Framenum': 5298},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/IMG_0003.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115313815.mp4',
#   'Type': 'frame',
#   'Framenum': 1734},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104426946.mp4',
#   'Type': 'frame',
#   'Framenum': 409},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115782501.mp4',
#   'Type': 'frame',
#   'Framenum': 2873},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105796987.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100176951.mp4',
#   'Type': 'frame',
#   'Framenum': 484},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100280012.mp4',
#   'Type': 'frame',
#   'Framenum': 1376},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107911515.mp4',
#   'Type': 'frame',
#   'Framenum': 1448},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116305241.mp4',
# ...
#   'Framenum': 767},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115294545.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103098431.mp4',
#   'Type': 'frame',
#   'Framenum': 957},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114645852.mp4',
#   'Type': 'frame',
#   'Framenum': 7024},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108292567.mp4',
#   'Type': 'frame',
#   'Framenum': 528},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113992697.mp4',
#   'Type': 'frame',
#   'Framenum': 1567},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112929509.mp4',
#   'Type': 'frame',
#   'Framenum': 3805},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115950662.mp4',
#   'Type': 'frame',
#   'Framenum': 516},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111709984.mp4',
#   'Type': 'frame',
#   'Framenum': 6626},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106678330.mp4',
#   'Type': 'frame',
#   'Framenum': 178},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115083455.mp4',
#   'Type': 'frame',
#   'Framenum': 785},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101301089.mp4',
#   'Type': 'frame',
#   'Framenum': 240},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113317550.mp4',
#   'Type': 'frame',
#   'Framenum': 392},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111547044.mp4',
#   'Type': 'frame',
#   'Framenum': 5398},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100445787.mp4',
#   'Type': 'frame',
#   'Framenum': 1064},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100475707.mp4',
#   'Type': 'frame',
#   'Framenum': 1496},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115436424.mp4',
#   'Type': 'frame',
#   'Framenum': 344},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115689482.mp4',
#   'Type': 'frame',
#   'Framenum': 4117},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114662840.mp4',
#   'Type': 'frame',
#   'Framenum': 510},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105052723.mp4',
#   'Type': 'frame',
#   'Framenum': 3344},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106137497.mp4',
#   'Type': 'frame',
#   'Framenum': 274},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116329421.mp4',
#   'Type': 'frame',
#   'Framenum': 1381},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/120061340.mp4',
#   'Type': 'frame',
#   'Framenum': 3093},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115193052.mp4',
#   'Type': 'frame',
#   'Framenum': 274},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115807413.mp4',
#   'Type': 'frame',
#   'Framenum': 350},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105918615.mp4',
#   'Type': 'frame',
#   'Framenum': 1945},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105726968.mp4',
#   'Type': 'frame',
#   'Framenum': 5996},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101876858.mp4',
#   'Type': 'frame',
#   'Framenum': 181},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112647038.mp4',
#   'Type': 'frame',
#   'Framenum': 1127},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101682307.mp4',
#   'Type': 'frame',
#   'Framenum': 3410},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108722445.mp4',
#   'Type': 'frame',
#   'Framenum': 656},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107201812.mp4',
#   'Type': 'frame',
#   'Framenum': 13082},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112233163.mp4',
#   'Type': 'frame',
#   'Framenum': 1008},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115766224.mp4',
#   'Type': 'frame',
#   'Framenum': 6032},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113506787.mp4',
#   'Type': 'frame',
#   'Framenum': 942},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106678329.mp4',
#   'Type': 'frame',
#   'Framenum': 178},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110371796.mp4',
#   'Type': 'frame',
#   'Framenum': 1346},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115542614.mp4',
#   'Type': 'frame',
#   'Framenum': 3696},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115193057.mp4',
#   'Type': 'frame',
#   'Framenum': 222},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114900085.mp4',
#   'Type': 'frame',
#   'Framenum': 4103},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112447933.mp4',
#   'Type': 'frame',
#   'Framenum': 4628},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113562893.mp4',
#   'Type': 'frame',
#   'Framenum': 1489},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105180543.mp4',
#   'Type': 'frame',
#   'Framenum': 918},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111463863.mp4',
#   'Type': 'frame',
#   'Framenum': 3166},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103928950.mp4',
#   'Type': 'frame',
#   'Framenum': 2960},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100457108.mp4',
#   'Type': 'frame',
#   'Framenum': 314},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102252780.mp4',
#   'Type': 'frame',
#   'Framenum': 966},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/107863021.mp4',
#   'Type': 'frame',
#   'Framenum': 3892},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114970140.mp4',
#   'Type': 'frame',
#   'Framenum': 1375},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110975666.mp4',
#   'Type': 'frame',
#   'Framenum': 1166},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110498281.mp4',
#   'Type': 'frame',
#   'Framenum': 1588},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109606931.mp4',
#   'Type': 'frame',
#   'Framenum': 2550},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116325630.mp4',
#   'Type': 'frame',
#   'Framenum': 2017},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113589503.mp4',
#   'Type': 'frame',
#   'Framenum': 1093},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110634101.mp4',
#   'Type': 'frame',
#   'Framenum': 3601},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110404881.mp4',
#   'Type': 'frame',
#   'Framenum': 1229},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115808081.mp4',
#   'Type': 'frame',
#   'Framenum': 436},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115252637.mp4',
#   'Type': 'frame',
#   'Framenum': 6545},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105977164.mp4',
#   'Type': 'frame',
#   'Framenum': 4502},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109183144.mp4',
#   'Type': 'frame',
#   'Framenum': 1896},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/178500853.mp4',
#   'Type': 'frame',
#   'Framenum': 15608},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103236156.mp4',
#   'Type': 'frame',
#   'Framenum': 780},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108835168.mp4',
#   'Type': 'frame',
#   'Framenum': 619},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106310219.mp4',
#   'Type': 'frame',
#   'Framenum': 4543},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111654355.mp4',
#   'Type': 'frame',
#   'Framenum': 1148},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108620151.mp4',
#   'Type': 'frame',
#   'Framenum': 241},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109948165.mp4',
#   'Type': 'frame',
#   'Framenum': 3899},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101250699.mp4',
#   'Type': 'frame',
#   'Framenum': 6644},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108620152.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115149694.mp4',
#   'Type': 'frame',
#   'Framenum': 483},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/269305059.mp4',
#   'Type': 'frame',
#   'Framenum': 2826},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100561672.mp4',
#   'Type': 'frame',
#   'Framenum': 523},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112137482.mp4',
#   'Type': 'frame',
#   'Framenum': 1365},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110557224.mp4',
#   'Type': 'frame',
#   'Framenum': 2311},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/420951241.mp4',
#   'Type': 'frame',
#   'Framenum': 1504},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102218144.mp4',
#   'Type': 'frame',
#   'Framenum': 1982},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110506586.mp4',
#   'Type': 'frame',
#   'Framenum': 726},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109090409.mp4',
#   'Type': 'frame',
#   'Framenum': 3510},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108413964.mp4',
#   'Type': 'frame',
#   'Framenum': 908},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103561089.mp4',
#   'Type': 'frame',
#   'Framenum': 2715},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115640710.mp4',
#   'Type': 'frame',
#   'Framenum': 63},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101410869.mp4',
#   'Type': 'frame',
#   'Framenum': 1095},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110864796.mp4',
#   'Type': 'frame',
#   'Framenum': 289},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108283714.mp4',
#   'Type': 'frame',
#   'Framenum': 333},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105052721.mp4',
#   'Type': 'frame',
#   'Framenum': 1109},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105189820.mp4',
#   'Type': 'frame',
#   'Framenum': 3383},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102037622.mp4',
#   'Type': 'frame',
#   'Framenum': 380},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109155150.mp4',
#   'Type': 'frame',
#   'Framenum': 2176},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104302392.mp4',
#   'Type': 'frame',
#   'Framenum': 2572},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116207909.mp4',
#   'Type': 'frame',
#   'Framenum': 5604},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104183690.mp4',
#   'Type': 'frame',
#   'Framenum': 480},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110600101.mp4',
#   'Type': 'frame',
#   'Framenum': 544},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100629929.mp4',
#   'Type': 'frame',
#   'Framenum': 1572},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100954161.mp4',
#   'Type': 'frame',
#   'Framenum': 1444},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103304504.mp4',
#   'Type': 'frame',
#   'Framenum': 1336},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111281866.mp4',
#   'Type': 'frame',
#   'Framenum': 2274},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/105394829.mp4',
#   'Type': 'frame',
#   'Framenum': 851},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100494682.mp4',
#   'Type': 'frame',
#   'Framenum': 1199},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102776966.mp4',
#   'Type': 'frame',
#   'Framenum': 5370},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112733956.mp4',
#   'Type': 'frame',
#   'Framenum': 14612},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102296071.mp4',
#   'Type': 'frame',
#   'Framenum': 1178},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110864798.mp4',
#   'Type': 'frame',
#   'Framenum': 187},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109184682.mp4',
#   'Type': 'frame',
#   'Framenum': 483},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109209109.mp4',
#   'Type': 'frame',
#   'Framenum': 1191},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114689109.mp4',
#   'Type': 'frame',
#   'Framenum': 1178},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109037717.mp4',
#   'Type': 'frame',
#   'Framenum': 416},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102692163.mp4',
#   'Type': 'frame',
#   'Framenum': 2162},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/116102029.mp4',
#   'Type': 'frame',
#   'Framenum': 3828},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115806848.mp4',
#   'Type': 'frame',
#   'Framenum': 237},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108476382.mp4',
#   'Type': 'frame',
#   'Framenum': 1915},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/102504511.mp4',
#   'Type': 'frame',
#   'Framenum': 1732},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114796787.mp4',
#   'Type': 'frame',
#   'Framenum': 2710},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/44060692.mp4',
#   'Type': 'frame',
#   'Framenum': 3922},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/IMG_0012.jpg',
#   'Type': 'image'},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112929510.mp4',
#   'Type': 'frame',
#   'Framenum': 654},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111514048.mp4',
#   'Type': 'frame',
#   'Framenum': 1119},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101170291.mp4',
#   'Type': 'frame',
#   'Framenum': 953},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115193051.mp4',
#   'Type': 'frame',
#   'Framenum': 405},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/111729211.mp4',
#   'Type': 'frame',
#   'Framenum': 1272},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/110514041.mp4',
#   'Type': 'frame',
#   'Framenum': 2460},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103211606.mp4',
#   'Type': 'frame',
#   'Framenum': 253},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/103342670.mp4',
#   'Type': 'frame',
#   'Framenum': 2807},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109484255.mp4',
#   'Type': 'frame',
#   'Framenum': 2832},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104268302.mp4',
#   'Type': 'frame',
#   'Framenum': 2161},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115295406.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100923368.mp4',
#   'Type': 'frame',
#   'Framenum': 481},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109188087.mp4',
#   'Type': 'frame',
#   'Framenum': 6343},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114200563.mp4',
#   'Type': 'frame',
#   'Framenum': 960},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/106369787.mp4',
#   'Type': 'frame',
#   'Framenum': 1164},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112602196.mp4',
#   'Type': 'frame',
#   'Framenum': 1156},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/112215570.mp4',
#   'Type': 'frame',
#   'Framenum': 6786},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/113638939.mp4',
#   'Type': 'frame',
#   'Framenum': 880},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/109449825.mp4',
#   'Type': 'frame',
#   'Framenum': 5054},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115024686.mp4',
#   'Type': 'frame',
#   'Framenum': 2778},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/104688084.mp4',
#   'Type': 'frame',
#   'Framenum': 3416},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/101643988.mp4',
#   'Type': 'frame',
#   'Framenum': 1597},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115022396.mp4',
#   'Type': 'frame',
#   'Framenum': 4991},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/100001237.mp4',
#   'Type': 'frame',
#   'Framenum': 2190},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/115830091.mp4',
#   'Type': 'frame',
#   'Framenum': 2337},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114043783.mp4',
#   'Type': 'frame',
#   'Framenum': 1570},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/114674220.mp4',
#   'Type': 'frame',
#   'Framenum': 2134},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/108052305.mp4',
#   'Type': 'frame',
#   'Framenum': 1005},
#  {'Filepath': '/media/SSD/superres/video_data/train_data/dad barbequeing_0004.jpg',
#   'Type': 'image'}]

# %%
def load_frame(instance):
    
    path = instance["Filepath"]
    
    if instance["Type"] == "frame":
        
        frame = instance["Framenum"]
        cap = cv2.VideoCapture(path)
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame-1)
        ret, img = cap.read()
        if ret==0:
            print("Error with:",instance)
    elif instance["Type"] == "image":
        img = cv2.imread(path)
    # convert to PIL RGB
    im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    return Image.fromarray(im_rgb)

# %%
class RescaleCrop(object):


    def __init__(self, crop_size ,kernel_width):
        
        if isinstance(crop_size, numbers.Number):
            self.crop_size = (int(crop_size), int(crop_size))
        else:
            self.crop_size = crop_size 
        
        self.kernel_width = kernel_width
        

    
        

    def __call__(self, img):
        
        
        # Ideal steps
        # Crop with proportional scale, to simulate images of different input resolutions (if thats a requirement)
        # This crop should leave some edges of the image to allow blurring with kernel beyond final size
        # Blur the image 
        # If different randomly picked blurring kernels are used, they should have equivalent blurring power.
        
        h_size,v_size = img.size
        
        #print("im size:", img.size)
        
        # Resize down to a size a bit larger than final size to allow proper blurring
        v_wanted = int(self.crop_size[0]+self.kernel_width+1)
        h_wanted = int(self.crop_size[1]+self.kernel_width+1)
        
        #print("im wanted:", (h_wanted, v_wanted))
        
        h_scale = h_wanted/h_size
        v_scale = v_wanted/v_size
        
        scale = max(h_scale, v_scale)
        
        #print("scales=",(h_scale, v_scale))
        
        #print("new size=",(int(h_size*scale), int(v_size*scale)))
        img = img.resize((int(h_size*scale), int(v_size*scale)))
        
        img = CenterCrop((v_wanted,h_wanted))(img) 

        
        return img

# %%
def tophat2D(r):
    
    d=2*int(r)+1
    Y, X = np.ogrid[:d, :d]
    c=int(r)
    k = (np.sqrt((X-c)**2 +  (Y-c)**2) <= r)*1 
    
    return k/k.sum()

# %%
def cv_center_crop(img,output_size):
        if isinstance(output_size, numbers.Number):
            output_size = (int(output_size), int(output_size))
            
        
        image_height = img.shape[0]
        image_width = img.shape[1]
        
        crop_height, crop_width = output_size
        crop_top = max(0,int(round((image_height - crop_height) / 2.)))
        crop_left = max(0,int(round((image_width - crop_width) / 2.)))
        #print("input:",img.shape)
        #print("output:",output_size)
        #print("crop:",crop_top,crop_top+output_size[0],crop_left,crop_left+output_size[1])
        return img[crop_top:crop_top+output_size[0],crop_left:crop_left+output_size[1]]

# %%
class CropRescale(object):


    def __init__(self, crop_size ,factor_range):
        
        if isinstance(crop_size, numbers.Number):
            self.crop_size = (int(crop_size), int(crop_size))
        else:
            self.crop_size = crop_size 
        
        self.factor_range = factor_range
        

    
        

    def __call__(self, img):
        
        rand_scale_factor = random.uniform(*self.factor_range)
        #print("size of image",img.size)
        
        # Ideal steps
        # Crop with proportional scale, to simulate images of different input resolutions (if thats a requirement)
        # This crop should leave some edges of the image to allow blurring with kernel beyond final size
        # Blur the image 
        # If different randomly picked blurring kernels are used, they should have equivalent blurring power.
        
        h_size,v_size = img.size
        
        #print("im size:", img.size)
        
        # Resize down to a size a bit larger than final size to allow proper blurring
        v_wanted = int(self.crop_size[0]+2*rand_scale_factor+2)
        h_wanted = int(self.crop_size[1]+2*rand_scale_factor+2)
        
        #print("im wanted:", (h_wanted, v_wanted))
        
        h_scale = h_wanted/h_size
        v_scale = v_wanted/v_size
        
        scale = max(h_scale, v_scale)
        
        #print("scales=",(h_scale, v_scale))
        
        #print("new size=",(int(h_size*scale), int(v_size*scale)))
        img = img.resize((int(h_size*scale), int(v_size*scale)))
        
        img_cv = cv_center_crop(np.array(img),(v_wanted,h_wanted))  

        
        #Disk Blur
        #print(max(np.array(img)), min(np.array(img)))
        img_cv = cv2.filter2D(img_cv, -1, tophat2D(rand_scale_factor))
    
        #Center Crop
        img_cv = cv_center_crop(img_cv,self.crop_size)
        
        #Jpeg compression (for adding artifacts)
        #rand_quality_factor = random.uniform(30,90)
        #is_success, im_buf_arr = cv2.imencode(".jpg", img_cv,params = [cv2.IMWRITE_JPEG_QUALITY,30])
        #img_cv = cv2.imdecode(im_buf_arr,flags=cv2.IMREAD_COLOR)
        
        
        img= Image.fromarray(img_cv)
        return img

# %%
class Crappify(object):


    def __init__(self, crop_size ,kernel_size, quality):
        
        if isinstance(crop_size, numbers.Number):
            self.crop_size = (int(crop_size), int(crop_size))
        else:
            self.crop_size = crop_size 
        
        self.kernel_size = kernel_size
        self.quality = quality

    
        

    def __call__(self, img):
        
        
        img_cv = np.array(img)

        
        #Disk Blur
        #print(max(np.array(img)), min(np.array(img)))
        
        k=tophat2D(int(self.kernel_size)/2.0)
        
        img_cv = cv2.filter2D(img_cv, -1, k)
    
        #Center Crop
        if self.crop_size is not None:
            img_cv = cv_center_crop(img_cv,self.crop_size)
        
        #Jpeg compression (for adding artifacts)
        rand_quality_factor = random.uniform(30,90)
        is_success, im_buf_arr = cv2.imencode(".jpg", img_cv,params = [cv2.IMWRITE_JPEG_QUALITY,self.quality])
        img_cv = cv2.imdecode(im_buf_arr,flags=cv2.IMREAD_COLOR)
        
        
        img= Image.fromarray(img_cv)
        return img

# %%
def create_circular_mask(h, w, slope=0.01, center=None, radius=None, scale=1.0):

    if center is None: # use the middle of the image
        center = (int(w/2), int(h/2))
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])

    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((scale*(X - center[0]))**2 + ((Y-center[1])/scale)**2)

    mask = np.minimum((np.maximum(dist_from_center-radius,0)*slope)**(0.5),1.0)
    return mask

# %%
tophat2D(2)
# Out:
# array([[0.        , 0.        , 0.07692308, 0.        , 0.        ],
#        [0.        , 0.07692308, 0.07692308, 0.07692308, 0.        ],
#        [0.07692308, 0.07692308, 0.07692308, 0.07692308, 0.07692308],
#        [0.        , 0.07692308, 0.07692308, 0.07692308, 0.        ],
#        [0.        , 0.        , 0.07692308, 0.        , 0.        ]])

# %%
class Multifuz(object):


    def __init__(self, crop_size ,kernel_a, kernel_b, quality, slope, radius, scale, center):
        
        if isinstance(crop_size, numbers.Number):
            self.crop_size = (int(crop_size), int(crop_size))
        else:
            self.crop_size = crop_size 
        
        self.kernel_a = kernel_a
        self.kernel_b = kernel_b
        self.quality = quality
        self.slope = slope
        self.radius = radius
        self.scale = scale
        self.center = center
        

    
        

    def __call__(self, img):
        
        img_cv = np.array(img)
        d = img_cv .shape
        dim = (d[1], d[0])
        height = d[0]
        width = d[1]
        color = len(d)-2
        
        
        #blur kernel A
        
        k = tophat2D(int(self.kernel_a)/2.0)
        img_cv_blurA = cv2.filter2D(img_cv, cv2.CV_32F, k)
        img_cv_blurA = cv_center_crop(img_cv_blurA,self.crop_size)
        
        #blur kernel B
        k = tophat2D(int(self.kernel_b)/2.0)
        img_cv_blurB = cv2.filter2D(img_cv, cv2.CV_32F, k)
        img_cv_blurB = cv_center_crop(img_cv_blurB,self.crop_size)
        
        #add them with a mask
        # Normalize the alpha mask to keep intensity between 0 and 1
        
        alpha = create_circular_mask(h=self.crop_size[0], w=self.crop_size[1], slope=self.slope,center=self.center,
                                     radius=self.radius, scale = self.scale)*1.0
        
        if color ==1:
            alpha=np.reshape(alpha, (self.crop_size[0],self.crop_size[1],-1))
            alpha=np.broadcast_to(alpha,[self.crop_size[0],self.crop_size[1],3])
        
        #alpha = alpha.astype(float)/255
        
        # Multiply the foreground with the alpha matte
        
        
        
        img_cv_blurA = cv2.multiply(img_cv_blurA, alpha, dtype=cv2.CV_32F )
        # Multiply the background with ( 1 - alpha )

        
        img_cv_blurB = cv2.multiply(img_cv_blurB, 1.0 - alpha, dtype=cv2.CV_32F)
        # Add the masked foreground and background.

        #img_cv = img_cv_blurA
        img_cv = cv2.add(img_cv_blurA, img_cv_blurB, dtype=cv2.CV_32F)
        
        img_cv = cv2.normalize(img_cv, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
        
        
        
    
        #Center Crop
        #img_cv = cv_center_crop(img_cv,self.crop_size)
        
        #Jpeg compression (for adding artifacts)
        
        is_success, im_buf_arr = cv2.imencode(".jpg", img_cv,params = [cv2.IMWRITE_JPEG_QUALITY,self.quality])
        img_cv = cv2.imdecode(im_buf_arr,flags=cv2.IMREAD_COLOR)
        
        
        img= Image.fromarray(img_cv)
        return img

# %%
#test the Multifuz transform
im=load_frame(instances[10])
#im = Grayscale(num_output_channels=1)(im)
im = RescaleCrop(crop_size=(480,720),kernel_width=10)(im)
im_res = Multifuz(crop_size = (480,720),
                  center=(360,240),
                  kernel_a=1, 
                  kernel_b=10,
                  quality=33.32, 
                  slope=.1,
                 radius=50,
                 scale=1)(im)
print(im.size,im_res.size)
type(im_res)
im_res
# Out:
# (731, 491) (720, 480)
# <PIL.Image.Image image mode=RGB size=720x480 at 0x7F9D24ACEA60>

# %%
class DatasetFromVideoFolder(data.Dataset):
    def __init__(self, video_dir,crop_size,frame_sample_size=10,max_kernel=10,Flip_hor=True,
                 Rand_bright_contrast=True, target_transform=None, **camera_params):
        
        #  add_noise=None, noise_std=3.0, Flip_hor=False,Rand_bright_contrast=False, kernel_width=10

        super(DatasetFromVideoFolder, self).__init__()
        self.video_frames = make_framelist(video_dir,frame_sample_size)
        
        self.Flip_hor = Flip_hor
        self.Rand_bright_contrast = Rand_bright_contrast
        self.crop_size = crop_size
        self.max_kernel = max_kernel
        self.target_transform = target_transform
        self.camera_params = camera_params
        self.input_transform = input_transform
        
    def camera_transform(self,img_hr):
        
        # go through the parameters and simulate the camera
        width, height = img_hr.size
               
        crop_top = max(0,int(round((height - self.crop_size[0]) / 2.)))
        crop_bottom = crop_top + self.crop_size[0]
        crop_left = max(0,int(round((width - self.crop_size[1]) / 2.)))
        crop_right = crop_left + self.crop_size[1]
        
        camera_specs = {}
        camera_specs["crop_size"] = np.int16(self.crop_size)
        
        camera_specs["center"] = np.int16((random.uniform(crop_left, crop_right),random.uniform(crop_top, crop_bottom)))
        
        camera_specs["scale"] = np.float32(random.uniform(0.5,2))
       
        
        camera_specs["kernel_a"] = np.float32(random.uniform(*self.camera_params["kernel_range"]))
        camera_specs["kernel_b"] = np.float32(random.uniform(*self.camera_params["kernel_range"]))
        camera_specs["quality"] = np.int16(random.uniform(*self.camera_params["quality_range"]))
        camera_specs["slope"] = np.float32(random.uniform(*self.camera_params["slope_range"]))
        camera_specs["radius"] = np.float32(random.uniform(*self.camera_params["radius_range"])*max(self.crop_size[0],self.crop_size[1]))
        
        img_lr = Multifuz(**camera_specs)(img_hr)
        return img_lr, camera_specs

    def __getitem__(self, index):
        img_hr = load_frame(self.video_frames[index])
        if self.crop_size is not None:
            img_hr = RescaleCrop(self.crop_size,self.max_kernel )(img_hr)
        
        if self.Flip_hor:
            img_hr = RandomHorizontalFlip()(img_hr)
        
        if self.Rand_bright_contrast:
            img_hr = ColorJitter(brightness=.2, contrast=.2)(img_hr)
        
        

        
        # go through the parameters and simulate the camera
        img_lr,camera_specs = self.camera_transform(img_hr)
            
        
        if self.input_transform:
            img_lr = self.input_transform()(img_lr)
        
        if self.target_transform:
            img_hr = self.target_transform(img_hr)
            
        print(camera_specs)
        return img_lr, img_hr, camera_specs

    def __len__(self):
        return len(self.video_frames)

# %%
def input_transform():
    
    
    return Compose([        
        Grayscale(num_output_channels=1),
        ToTensor(),
    ])



def target_transform():
    return Compose([
        Grayscale(num_output_channels=1),
        ToTensor(),
    ])



def test_input_transform(crop_size, kernel_size, quality):
    
    return Compose([
        Crappify(crop_size=crop_size, kernel_size=kernel_size, quality=quality),
        ToTensor()
    ])


def get_training_set(data_dir, crop_size, kernel_range, frame_sample_size=10, add_noise=None, 
                     noise_std=3.0,Flip_hor=True,Rand_bright_contrast=True):
    

    cropsize = crop_size
    return DatasetFromVideoFolder(data_dir,crop_size, frame_sample_size,
                             input_transform=input_transform(
                                 crop_size, kernel_range),
                             target_transform=target_transform(crop_size),
                             add_noise=add_noise,
                             noise_std=noise_std,Flip_hor=Flip_hor,
                             Rand_bright_contrast=Rand_bright_contrast)


## Below functions need work

def get_validation_set(data_dir, crop_size, kernel_range):
    
    
    return DatasetFromVideoFolder(data_dir,frame_sample_size,
                             input_transform=input_transform(
                                 cropsize, kernel_range,frame_sample_size=10),
                             target_transform=target_transform(cropsize))


def get_test_set(data_dir, crop_size, kernel_size, quality, frame_sample_size=10):


    return DatasetFromVideoFolder(data_dir,crop_size, frame_sample_size,
                             input_transform=test_input_transform(
                                 crop_size, kernel_size, quality),
                             target_transform=ToTensor(),
                             add_noise=None,
                             noise_std=3,Flip_hor=False,
                             Rand_bright_contrast=False)

# %%
train_dir = "/media/SSD/superres/video_data/train_data"
frame_sample_size =1
batch_size = 4 # Make 4 For FP16, 480x720 size images
crop_size = (480,720)
#crop_size = (256,256)
kernel_range=(1,10)
quality_range=(30,90) 
slope_range=(0.00001, 0.01)
radius_range=(.05,.75)
scale_range=(1/2,2)
Flip_hor=True
Rand_bright_contrast=True

# %%
train_set = DatasetFromVideoFolder(train_dir,crop_size,frame_sample_size,
                                   input_transform=input_transform(),
                                   target_transform=target_transform(),
                                   Flip_hor=Flip_hor,
                                   Rand_bright_contrast=Rand_bright_contrast,
                                   kernel_range=kernel_range,
                                   quality_range=quality_range,
                                   slope_range=slope_range,
                                   radius_range=radius_range,
                                   scale_range=scale_range,
                                   max_kernel=10
                            )
training_data_loader = DataLoader(dataset=train_set, num_workers=0, batch_size=batch_size, shuffle=True)

# %%
# create a data set
# split it using random split
# random_split(range(10), [3, 7], generator=torch.Generator().manual_seed(42))

# %% [markdown]
# train_set = get_training_set(data_dir=train_dir, crop_size=crop_size,
#             kernel_range=kernel_range,frame_sample_size =frame_sample_size,
#             add_noise=add_noise, noise_std=noise_std,Flip_hor=Flip_hor,Rand_bright_contrast=Rand_bright_contrast)
# training_data_loader = DataLoader(dataset=train_set, num_workers=0, batch_size=batch_size, shuffle=True)

# %%
# measurement of blur of an image
def variance_of_laplacian(image):
    # compute the Laplacian of the image and then return the focus
    # measure, which is simply the variance of the Laplacian
    return cv2.Laplacian(image, cv2.CV_64F).var()

# %%
def show_batch(dataloader,size = 8):

    inputs, outputs, camera_specs = next(iter(dataloader))
    print(inputs.shape)
    inputs = inputs.numpy().transpose((0, 2, 3, 1))
    outputs = outputs.numpy().transpose((0, 2, 3, 1))
    print(camera_specs)
    
    #mean = np.array([0.485, 0.456, 0.406])
    #std = np.array([0.229, 0.224, 0.225])
    #inputs = inputs*std + mean
    #outputs = outputs*std + mean
    w,h = 2*size, 4*size
    fig=plt.figure(figsize=(w, h))
    columns = 2
    rows = 4
    ax=[]
    
    for i in range(0, rows):
        blur_measure_input = variance_of_laplacian((inputs[i]*255).astype(np.uint8))
        blur_measure_output = variance_of_laplacian((outputs[i]*255).astype(np.uint8))
        ax.append(fig.add_subplot(rows, columns, 2*i+1))
        ax[-1].set_title('Blur: '+str(blur_measure_input))
        plt.imshow((inputs[i]*255).astype(np.uint8),cmap='gray')
        ax.append(fig.add_subplot(rows, columns, 2*i+2))
        ax[-1].set_title('Blur: '+str(blur_measure_output))
        plt.imshow((outputs[i]*255).astype(np.uint8),cmap='gray')
    plt.show()

# %%
show_batch(training_data_loader,size =8)
# Out:
# {'crop_size': array([480, 720], dtype=int16), 'center': array([259, 201], dtype=int16), 'scale': 1.3031404, 'kernel_a': 9.735499, 'kernel_b': 8.594054, 'quality': 39, 'slope': 0.003210989, 'radius': 79.99725}
# {'crop_size': array([480, 720], dtype=int16), 'center': array([254, 142], dtype=int16), 'scale': 1.105461, 'kernel_a': 2.657373, 'kernel_b': 2.7215676, 'quality': 58, 'slope': 0.009546904, 'radius': 343.28247}
# {'crop_size': array([480, 720], dtype=int16), 'center': array([266, 160], dtype=int16), 'scale': 0.54675764, 'kernel_a': 1.2178731, 'kernel_b': 4.242602, 'quality': 81, 'slope': 0.0077786413, 'radius': 447.63156}
# {'crop_size': array([480, 720], dtype=int16), 'center': array([463, 395], dtype=int16), 'scale': 0.87342095, 'kernel_a': 4.9971824, 'kernel_b': 5.506271, 'quality': 56, 'slope': 0.007869268, 'radius': 299.26688}
# torch.Size([4, 1, 480, 720])
# {'crop_size': tensor([[480, 720],
#         [480, 720],
#         [480, 720],
#         [480, 720]], dtype=torch.int16), 'center': tensor([[259, 201],
#         [254, 142],
#         [266, 160],
#         [463, 395]], dtype=torch.int16), 'scale': tensor([1.3031, 1.1055, 0.5468, 0.8734]), 'kernel_a': tensor([9.7355, 2.6574, 1.2179, 4.9972]), 'kernel_b': tensor([8.5941, 2.7216, 4.2426, 5.5063]), 'quality': tensor([39, 58, 81, 56], dtype=torch.int16), 'slope': tensor([0.0032, 0.0095, 0.0078, 0.0079]), 'radius': tensor([ 79.9973, 343.2825, 447.6316, 299.2669])}

# %% [markdown]
# # MWCNN
# https://github.com/lpj-github-io/MWCNNv2/blob/master/MWCNN_code/model/mwcnn.py

# %%
import math

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable

def default_conv(in_channels, out_channels, kernel_size, bias=True, dilation=1):
    return nn.Conv2d(
        in_channels, out_channels, kernel_size,
        padding=(kernel_size//2)+dilation-1, bias=bias, dilation=dilation)


def default_conv1(in_channels, out_channels, kernel_size, bias=True, groups=3):
    return nn.Conv2d(
        in_channels,out_channels, kernel_size,
        padding=(kernel_size//2), bias=bias, groups=groups)

#def shuffle_channel()

def channel_shuffle(x, groups):
    batchsize, num_channels, height, width = x.size()

    channels_per_group = num_channels // groups

    # reshape
    x = x.view(batchsize, groups,
               channels_per_group, height, width)

    x = torch.transpose(x, 1, 2).contiguous()

    # flatten
    x = x.view(batchsize, -1, height, width)

    return x

def pixel_down_shuffle(x, downsacale_factor):
    batchsize, num_channels, height, width = x.size()

    out_height = height // downsacale_factor
    out_width = width // downsacale_factor
    input_view = x.contiguous().view(batchsize, num_channels, out_height, downsacale_factor, out_width,
                                     downsacale_factor)

    num_channels *= downsacale_factor ** 2
    unshuffle_out = input_view.permute(0,1,3,5,2,4).contiguous()

    return unshuffle_out.view(batchsize, num_channels, out_height, out_width)



def sp_init(x):

    x01 = x[:, :, 0::2, :]
    x02 = x[:, :, 1::2, :]
    x_LL = x01[:, :, :, 0::2]
    x_HL = x02[:, :, :, 0::2]
    x_LH = x01[:, :, :, 1::2]
    x_HH = x02[:, :, :, 1::2]


    return torch.cat((x_LL, x_HL, x_LH, x_HH), 1)

def dwt_init(x):

    x01 = x[:, :, 0::2, :] / 2
    x02 = x[:, :, 1::2, :] / 2
    x1 = x01[:, :, :, 0::2]
    x2 = x02[:, :, :, 0::2]
    x3 = x01[:, :, :, 1::2]
    x4 = x02[:, :, :, 1::2]
    x_LL = x1 + x2 + x3 + x4
    x_HL = -x1 - x2 + x3 + x4
    x_LH = -x1 + x2 - x3 + x4
    x_HH = x1 - x2 - x3 + x4

    return torch.cat((x_LL, x_HL, x_LH, x_HH), 1)

def iwt_init(x):
    r = 2
    in_batch, in_channel, in_height, in_width = x.size()
    #print([in_batch, in_channel, in_height, in_width])
    out_batch, out_channel, out_height, out_width = in_batch, int(
        in_channel / (r ** 2)), r * in_height, r * in_width
    x1 = x[:, 0:out_channel, :, :] / 2
    x2 = x[:, out_channel:out_channel * 2, :, :] / 2
    x3 = x[:, out_channel * 2:out_channel * 3, :, :] / 2
    x4 = x[:, out_channel * 3:out_channel * 4, :, :] / 2
    

    h = torch.zeros([out_batch, out_channel, out_height, out_width]).float().cuda()

    h[:, :, 0::2, 0::2] = x1 - x2 - x3 + x4
    h[:, :, 1::2, 0::2] = x1 - x2 + x3 - x4
    h[:, :, 0::2, 1::2] = x1 + x2 - x3 - x4
    h[:, :, 1::2, 1::2] = x1 + x2 + x3 + x4

    return h

class Channel_Shuffle(nn.Module):
    def __init__(self, conv_groups):
        super(Channel_Shuffle, self).__init__()
        self.conv_groups = conv_groups
        self.requires_grad = False

    def forward(self, x):
        return channel_shuffle(x, self.conv_groups)

class SP(nn.Module):
    def __init__(self):
        super(SP, self).__init__()
        self.requires_grad = False

    def forward(self, x):
        return sp_init(x)

class Pixel_Down_Shuffle(nn.Module):
    def __init__(self):
        super(Pixel_Down_Shuffle, self).__init__()
        self.requires_grad = False

    def forward(self, x):
        return pixel_down_shuffle(x, 2)

class DWT(nn.Module):
    def __init__(self):
        super(DWT, self).__init__()
        self.requires_grad = False

    def forward(self, x):
        return dwt_init(x)

class IWT(nn.Module):
    def __init__(self):
        super(IWT, self).__init__()
        self.requires_grad = False

    def forward(self, x):
        return iwt_init(x)


class MeanShift(nn.Conv2d):
    def __init__(self, rgb_range, rgb_mean, rgb_std, sign=-1):
        super(MeanShift, self).__init__(3, 3, kernel_size=1)
        std = torch.Tensor(rgb_std)
        self.weight.data = torch.eye(3).view(3, 3, 1, 1)
        self.weight.data.div_(std.view(3, 1, 1, 1))
        self.bias.data = sign * rgb_range * torch.Tensor(rgb_mean)
        self.bias.data.div_(std)
        self.requires_grad = False
        if sign==-1:
            self.create_graph = False
            self.volatile = True
class MeanShift2(nn.Conv2d):
    def __init__(self, rgb_range, rgb_mean, rgb_std, sign=-1):
        super(MeanShift2, self).__init__(4, 4, kernel_size=1)
        std = torch.Tensor(rgb_std)
        self.weight.data = torch.eye(4).view(4, 4, 1, 1)
        self.weight.data.div_(std.view(4, 1, 1, 1))
        self.bias.data = sign * rgb_range * torch.Tensor(rgb_mean)
        self.bias.data.div_(std)
        self.requires_grad = False
        if sign==-1:
            self.volatile = True

class BasicBlock(nn.Sequential):
    def __init__(
        self, in_channels, out_channels, kernel_size, stride=1, bias=False,
        bn=False, act=nn.ReLU(True)):

        m = [nn.Conv2d(
            in_channels, out_channels, kernel_size,
            padding=(kernel_size//2), stride=stride, bias=bias)
        ]
        if bn: m.append(nn.BatchNorm2d(out_channels))
        if act is not None: m.append(act)
        super(BasicBlock, self).__init__(*m)

class BBlock(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(BBlock, self).__init__()
        m = []
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x).mul(self.res_scale)
        return x

class DBlock_com(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DBlock_com, self).__init__()
        m = []

        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=3))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x)
        return x

class DBlock_inv(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DBlock_inv, self).__init__()
        m = []

        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=3))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x)
        return x

class DBlock_com1(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DBlock_com1, self).__init__()
        m = []

        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=1))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x)
        return x

class DBlock_inv1(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DBlock_inv1, self).__init__()
        m = []

        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=1))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x)
        return x

class DBlock_com2(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DBlock_com2, self).__init__()
        m = []

        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x)
        return x

class DBlock_inv2(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DBlock_inv2, self).__init__()
        m = []

        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias, dilation=2))
        if bn: m.append(nn.BatchNorm2d(out_channels, eps=1e-4, momentum=0.95))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x)
        return x

class ShuffleBlock(nn.Module):
    def __init__(
        self, conv, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1,conv_groups=1):

        super(ShuffleBlock, self).__init__()
        m = []
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias))
        m.append(Channel_Shuffle(conv_groups))
        if bn: m.append(nn.BatchNorm2d(out_channels))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x).mul(self.res_scale)
        return x


class DWBlock(nn.Module):
    def __init__(
        self, conv, conv1, in_channels, out_channels, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(DWBlock, self).__init__()
        m = []
        m.append(conv(in_channels, out_channels, kernel_size, bias=bias))
        if bn: m.append(nn.BatchNorm2d(out_channels))
        m.append(act)

        m.append(conv1(in_channels, out_channels, 1, bias=bias))
        if bn: m.append(nn.BatchNorm2d(out_channels))
        m.append(act)


        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        x = self.body(x).mul(self.res_scale)
        return x

class ResBlock(nn.Module):
    def __init__(
        self, conv, n_feat, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(ResBlock, self).__init__()
        m = []
        for i in range(2):
            m.append(conv(n_feat, n_feat, kernel_size, bias=bias))
            if bn: m.append(nn.BatchNorm2d(n_feat))
            if i == 0: m.append(act)

        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        res = self.body(x).mul(self.res_scale)
        res += x

        return res

class Block(nn.Module):
    def __init__(
        self, conv, n_feat, kernel_size,
        bias=True, bn=False, act=nn.ReLU(True), res_scale=1):

        super(Block, self).__init__()
        m = []
        for i in range(4):
            m.append(conv(n_feat, n_feat, kernel_size, bias=bias))
            if bn: m.append(nn.BatchNorm2d(n_feat))
            if i == 0: m.append(act)

        self.body = nn.Sequential(*m)
        self.res_scale = res_scale

    def forward(self, x):
        res = self.body(x).mul(self.res_scale)
        # res += x

        return res

class Upsampler(nn.Sequential):
    def __init__(self, conv, scale, n_feat, bn=False, act=False, bias=True):

        m = []
        if (scale & (scale - 1)) == 0:    # Is scale = 2^n?
            for _ in range(int(math.log(scale, 2))):
                m.append(conv(n_feat, 4 * n_feat, 3, bias))
                m.append(nn.PixelShuffle(2))
                if bn: m.append(nn.BatchNorm2d(n_feat))
                if act: m.append(act())
        elif scale == 3:
            m.append(conv(n_feat, 9 * n_feat, 3, bias))
            m.append(nn.PixelShuffle(3))
            if bn: m.append(nn.BatchNorm2d(n_feat))
            if act: m.append(act())
        else:
            raise NotImplementedError

        super(Upsampler, self).__init__(*m)

# %%
import torch
import torch.nn as nn
import scipy.io as sio

def make_model(args, parent=False):
    return MWCNN(args)

class MWCNN(nn.Module):
    def __init__(self, args, conv=default_conv):
        super(MWCNN, self).__init__()
        n_resblocks = args.n_resblocks
        n_feats = args.n_feats
        kernel_size = 3
        self.scale_idx = 0
        nColor = args.n_colors

        act = nn.ReLU(True)

        self.DWT = DWT()
        self.IWT = IWT()

        n = 1
        m_head = [BBlock(conv, nColor, n_feats, kernel_size, act=act)]
        d_l0 = []
        d_l0.append(DBlock_com1(conv, n_feats, n_feats, kernel_size, act=act, bn=False))


        d_l1 = [BBlock(conv, n_feats * 4, n_feats * 2, kernel_size, act=act, bn=False)]
        d_l1.append(DBlock_com1(conv, n_feats * 2, n_feats * 2, kernel_size, act=act, bn=False))

        d_l2 = []
        d_l2.append(BBlock(conv, n_feats * 8, n_feats * 4, kernel_size, act=act, bn=False))
        d_l2.append(DBlock_com1(conv, n_feats * 4, n_feats * 4, kernel_size, act=act, bn=False))
        pro_l3 = []
        pro_l3.append(BBlock(conv, n_feats * 16, n_feats * 8, kernel_size, act=act, bn=False))
        pro_l3.append(DBlock_com(conv, n_feats * 8, n_feats * 8, kernel_size, act=act, bn=False))
        pro_l3.append(DBlock_inv(conv, n_feats * 8, n_feats * 8, kernel_size, act=act, bn=False))
        pro_l3.append(BBlock(conv, n_feats * 8, n_feats * 16, kernel_size, act=act, bn=False))

        i_l2 = [DBlock_inv1(conv, n_feats * 4, n_feats * 4, kernel_size, act=act, bn=False)]
        i_l2.append(BBlock(conv, n_feats * 4, n_feats * 8, kernel_size, act=act, bn=False))

        i_l1 = [DBlock_inv1(conv, n_feats * 2, n_feats * 2, kernel_size, act=act, bn=False)]
        i_l1.append(BBlock(conv, n_feats * 2, n_feats * 4, kernel_size, act=act, bn=False))

        i_l0 = [DBlock_inv1(conv, n_feats, n_feats, kernel_size, act=act, bn=False)]

        m_tail = [conv(n_feats, nColor, kernel_size)]

        self.head = nn.Sequential(*m_head)
        self.d_l2 = nn.Sequential(*d_l2)
        self.d_l1 = nn.Sequential(*d_l1)
        self.d_l0 = nn.Sequential(*d_l0)
        self.pro_l3 = nn.Sequential(*pro_l3)
        self.i_l2 = nn.Sequential(*i_l2)
        self.i_l1 = nn.Sequential(*i_l1)
        self.i_l0 = nn.Sequential(*i_l0)
        self.tail = nn.Sequential(*m_tail)

    def forward(self, x):
        x0 = self.d_l0(self.head(x))
        x1 = self.d_l1(self.DWT(x0))
        x2 = self.d_l2(self.DWT(x1))
        x_ = self.IWT(self.pro_l3(self.DWT(x2))) + x2
        x_ = self.IWT(self.i_l2(x_)) + x1
        x_ = self.IWT(self.i_l1(x_)) + x0
        x = self.tail(self.i_l0(x_)) + x

        return x

    def set_scale(self, scale_idx):
        self.scale_idx = scale_idx

# %% [markdown]
# # build the model

# %%
from types import SimpleNamespace

args = SimpleNamespace()


args.n_resblocks = 20 # was 20
args.n_feats = 64
args.n_colors = 1

#args.n_resgroups = 5 # was 10
#args.reduction = 16
#args.scale = (1,0)
#args.rgb_range = 255

#args.res_scale = 1

# %%
model = MWCNN(args)
model.cuda()

# %%
num_pixels = crop_size[0] * crop_size[1]

# %%
def loss_scaler(im):
    # scale to -1,1 and convert to 3 channel (greyscale to RBG)
    return (im * 2 - 1).expand(-1, 3, -1, -1)

# %%
class Pixel_Loss(torch.nn.Module):
    
    def __init__(self,num_pixels):
        super(Pixel_Loss,self).__init__()
        self.lossfn = nn.MSELoss(reduction = 'mean')
        
        #self.percep_loss_fn = lpips.LPIPS(net='alex').cuda()


        self.num_pixels = num_pixels
    def forward(self,x,y):
        
        return self.num_pixels*(self.lossfn.forward(x,y))
    
    
    #def forward(self,x,y):
        
        #totloss = torch.mean(self.percep_loss_fn.forward(loss_scaler(x),loss_scaler(y)))
        
        #totloss.add_(self.lossfn.forward(x,y))
        
        
        #return totloss

# %%
criterion = Pixel_Loss(num_pixels)

# %%
init_lr = .001
lr_step = 2
gradient_clip = 0.4
epochs = 10

# %%
#optimizer = optim.SGD(model.parameters(), lr=init_lr, momentum=0.9, weight_decay=1e-4)
optimizer = optim.Adam(model.parameters(), lr=init_lr, weight_decay=1e-4)

# %%
scheduler = optim.lr_scheduler.OneCycleLR(optimizer, 
                                          max_lr=0.01,
                                          steps_per_epoch=len(training_data_loader),
                                          epochs=epochs)

# %%
def adjust_learning_rate(optimizer, epoch):
    """Sets the learning rate to the initial LR decayed by 10**0.5 every 3 epochs"""
    lr = init_lr * (0.1 ** (.5*(epoch // lr_step)))
    return lr

# %%
def save_checkpoint(experiment, model, epoch):

    model_out_str = str(model_out_path/(model_name_base+"_epoch_{}.pth")).format(epoch)
    
    state = {"experiment": experiment, "epoch": epoch ,"model": model}

    torch.save(state, model_out_str)

    print("Checkpoint saved to {}".format(model_out_str))

# %%
import datetime
from torch.cuda.amp import autocast
from torch.cuda.amp import GradScaler
#import kornia

# %%
from torch.optim.swa_utils import AveragedModel
swa_model = torch.optim.swa_utils.AveragedModel(model)

# %%
def trainfp16(training_data_loader, optimizer, scheduler, model, criterion, epoch,scaler):
    dt = str(datetime.datetime.now())
    print("Start Time:", dt)
    
    lr = adjust_learning_rate(optimizer, epoch-1)

    for param_group in optimizer.param_groups:
        param_group["lr"] = lr

    print("Epoch = {}, lr = {}".format(epoch, optimizer.param_groups[0]["lr"]))

    model.train()
    cum_loss2=0
    cum_loss = 0
    ct=0
    ct2=0

    for iteration, batch in enumerate(training_data_loader, 1):
        input = Variable(batch[0], requires_grad=False)
        target = Variable(batch[1], requires_grad=False)
        camera_specs = Variable(batch[2], requires_grad=False)
        
        input = input.cuda()
        
        target = target.cuda()
        
        optimizer.zero_grad()
        
        # Runs the forward pass with autocasting.
        with autocast():
            output = model(input)
            loss = criterion(output, target)
            
        
        
        
        scaler.scale(loss).backward()
        #loss.backward() 
        
        # Unscales the gradients of optimizer's assigned params in-place
        scaler.unscale_(optimizer)
        
        nn.utils.clip_grad_norm_(model.parameters(),gradient_clip) 
        
        #optimizer.step()
        scaler.step(optimizer)
        
        if epoch>1:
            swa_model.update_parameters(model)
        
        # Updates the scale for next iteration.
        scaler.update()
        
        #scheduler.step()
        
        cum_loss = cum_loss + loss.data
        cum_loss2 = cum_loss2 + loss.data
        ct2=ct2+batch_size
        ct = ct +batch_size
        

        if iteration%10 == 0:
            dt = str(datetime.datetime.now())
            print("===> Time: {} Epoch[{}]({}/{}): LR: {} : Loss: {:.10f}".format(dt,epoch, iteration, len(training_data_loader), optimizer.param_groups[0]["lr"], cum_loss/ct))
            ct=0
            cum_loss =0
   
    print("Epoch Loss:", cum_loss2/ct2)

# %%
# Creates a GradScaler once at the beginning of training for mixed precision
scaler = GradScaler()


for epoch in range(1, epochs+1):
        trainfp16(training_data_loader, optimizer, scheduler, model, criterion, epoch,scaler)
        save_checkpoint(NOTEBOOK_FULL_PATH, model, epoch)

# %% [markdown]
# Function that takes in a .mp4 video file and applies intrinsic matrix and distortion coefficients to undistort a video.  It also preserves the sound. it uses ffmpeg for some processing as well as opencv cv2 library.

# %%
# Define the colorization function
# We'll reuse the Cb and Cr channels from bicubic interpolation
def colorize_cv(y, ycbcr): 
    img = np.zeros((y.shape[0], y.shape[1], 3), np.uint8)
    img[:,:,0] = y
    img[:,:,1] = ycbcr[:,:,1]
    img[:,:,2] = ycbcr[:,:,2]
    img = cv2.cvtColor(img, cv2.COLOR_YCrCb2BGR)
    return img

# %%
def decolorize_cv(frame):
    im_ycbcr = cv2.cvtColor(frame, cv2.COLOR_BGR2YCR_CB)
    im_b_y = im_ycbcr[:,:,0].astype(float)
    im_grey = im_b_y/255.0
    return im_grey, im_ycbcr

# %%
from torch.cuda.amp import autocast
def superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=True,bitrate= "12000k",errorfile = None):
    
    model = model.cuda()
    #torch.set_grad_enabled(False)
    #model.eval()
    
    cap = cv2.VideoCapture(str(infile))
    
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)
    
    success_flag = False
    
    print("Original File:", str(infile))
    print("frames=",length,"\nwidth=",width,"\nheight=",height,"\nfps=",fps)
    
    

    new_height = int(height*factor)
    new_width = int(width*factor)
    
    print("\nProcess File:", str(outfile))
    print("factor:",factor,"\nwidth=",new_width, "\nheight=",new_height,"\nbitrate=",bitrate)
    
    

    dimension = '{}x{}'.format(new_width, new_height)  #ffmpeg uses bicubic as default scaling alg
    f_format = 'bgr24' # remember OpenCV uses bgr format




    command = ['ffmpeg',
            '-y',
            '-f', 'rawvideo',
            '-vcodec','rawvideo',
            '-s', dimension,
            '-pix_fmt', 'bgr24',
            '-r', str(fps),
            '-i', '-',
            '-i', str(infile),
            '-c:v', 'h264',
            '-c:a', 'aac',

            '-map','0:v:0',
            '-map','1:a:0',
            '-shortest',
            '-b:v', bitrate, 
            str(outfile) ]


    if errorfile is not None:
        ef = open(error_file,"w+")
        p = sp.Popen(command, stdin=sp.PIPE, stderr=ef)
    else:
        p = sp.Popen(command, stdin=sp.PIPE)

    # Full processing with a stream instead of a temp file for video
    pbar = tqdm(total=length)
    while(cap.isOpened()):




        # Capture frame-by-frame
        ret, frame = cap.read()
        if ret == True:
            
            if (factor != 1.0):
                frame = cv2.resize(frame, (new_width, new_height), interpolation=cv2.INTER_LANCZOS4)
            
            if channels == 1:
                im_input, im_b_ycbcr = decolorize_cv(frame)

                im_input = Variable(torch.from_numpy(im_input).float()).view(1, -1, im_input.shape[0], im_input.shape[1])
                im_input = im_input.cuda()

                with autocast():
                    out = model(im_input)
                out = (out*255.0).clamp(0,255)

                out = out.cpu()

                im_h_y = out.data[0].numpy().astype(np.float32)

                im_h_y = im_h_y[0,:,:]

                im_h = colorize_cv(im_h_y, im_b_ycbcr)
            elif channels == 3:
                im_input = frame/255.
                im_input = Variable(torch.from_numpy(im_input).float()).\
                view(1, 3, im_input.shape[0], im_input.shape[1])
        
  
                im_input = im_input.cuda()
    
                
                
                with autocast():
                    out = model(im_input)
                out = (out*255.0).clamp(0,255)

                out = out.cpu()
                
                im_h = out.data[0].view(im_input.shape[2], im_input.shape[3],3).numpy().astype(np.uint8)

                #im_h = out.data[0].numpy().astype(np.float32)

            
                

            p.stdin.write(im_h.tobytes())


            if display:
                cv2.imshow('Processed',im_h)
                time.sleep(10)
                #cv2.imshow('Orig',frame)
            pbar.update(1)
            # Press Q on keyboard to  exit
            if cv2.waitKey(25) & 0xFF == ord('q'):
                success_flag = False
                break
        # Break the loop
        else:
            success_flag = True
            break
    # When everything done, release the video capture object

    pbar.close()

    p.stdin.close()
    p.wait()

    cap.release()

    # Closes all the frames
    cv2.destroyAllWindows()
    
    return success_flag

# %% [markdown]
# # compare to benchmarks

# %%
from PIL import Image
import math
import matplotlib.pyplot as plt

# %%
# Here is the function for PSNR calculation
def PSNR(pred, gt, shave_border=0):
    height, width = pred.shape[:2]
    pred = pred[shave_border:height - shave_border, shave_border:width - shave_border]
    gt = gt[shave_border:height - shave_border, shave_border:width - shave_border]
    imdff = pred - gt
    rmse = math.sqrt(np.mean(imdff ** 2))
    if rmse == 0:
        return 100
    return 20 * math.log10(255.0 / rmse)

# %%
# Define the colorization function
# We'll reuse the Cb and Cr channels from bicubic interpolation
def colorize(y, ycbcr): 
    img = np.zeros((y.shape[0], y.shape[1], 3), np.uint8)
    img[:,:,0] = y
    img[:,:,1] = ycbcr[:,:,1]
    img[:,:,2] = ycbcr[:,:,2]
    img = Image.fromarray(img, "YCbCr").convert("RGB")
    return img

# %%
def decolorize(x):
    x_ycbcr = cv2.cvtColor(x, cv2.COLOR_BGR2YCR_CB)
    x_y = x_ycbcr[:,:,0].astype(float)
    return x_y, x_ycbcr

# %%
percept_loss= Pixel_Loss(num_pixels)

# %%
def display_PSNR(im_gt, im_b, im_in, model,channels=1, display=True):
    

    # Convert the images into YCbCr mode and extraction the Y channel (for PSNR calculation)
    im_gt_ycbcr = np.array(im_gt.convert("YCbCr"))
    im_b_ycbcr = np.array(im_b.convert("YCbCr"))
    im_in_ycbcr = np.array(im_in.convert("YCbCr"))
    
    im_gt_y = im_gt_ycbcr[:,:,0].astype(float)
    im_b_y = im_b_ycbcr[:,:,0].astype(float)
    im_in_y = im_in_ycbcr[:,:,0].astype(float)
    
    #psnr_bicubic = PSNR(im_gt_y, im_b_y)
    #psnr_input = PSNR(im_gt_y, im_in_y)
    psnr_bicubic = PSNR(np.array(im_gt),np.array( im_b))
    psnr_input = PSNR(np.array(im_gt), np.array(im_in))
    
    im_i_ycbcr = np.array(im_in.convert("YCbCr"))
    im_i_y = im_i_ycbcr[:,:,0].astype(float)
        
    # Prepare for the input, a pytorch tensor
    if channels == 1:
        im_input = im_i_y/255.
        im_input = Variable(torch.from_numpy(im_input).float()).\
        view(1, -1, im_input.shape[0], im_input.shape[1])
    
    if channels ==3:
        im_input = np.array(im_in)/255.0
        #im_input = np.array(im_in)
        im_input = Variable(torch.from_numpy(im_input).float()).\
        view(1, 3, im_input.shape[0], im_input.shape[1])
        
    #print("im_input.shape=",im_input.shape)    
    im_input = im_input.cuda()
    
    with autocast():
        out = model(im_input)
    
    out = (out*255.0).clamp(0,255)
    
    out = out.cpu()
    
    if channels == 1:
        im_y = out.data[0].numpy().astype(np.float32)
        im_h_y = im_y[0,:,:]
        im_h = np.array(colorize(im_h_y, im_b_ycbcr))

    elif channels ==3:
        #print("out[0]=",out[0].shape)
        #print("out.data[0]=",out.data[0].shape)
        #print("im_input.shape=",im_input.shape)
        im_h = out.data[0].view(im_input.shape[2], im_input.shape[3],3).numpy().astype(np.uint8)
        #print("im.h.shape=",im_h.shape)
        im_h_y, _ = decolorize(im_h)
        
    
    # Calculate the PNSR for prediction
    #psnr_predicted = PSNR(im_gt_y, im_h_y)
    psnr_predicted = PSNR(np.array(im_gt), np.array(im_h))
    
    
    # Calculate the PNSR different between bicubic interpolation and vdsr prediction
    
    
    
    blur_measure_gt = variance_of_laplacian((im_gt_y).astype(np.uint8))
    blur_measure_bicubic = variance_of_laplacian((im_b_y).astype(np.uint8))
    blur_measure_input = variance_of_laplacian((im_i_y).astype(np.uint8))
    blur_measure_vdsr = variance_of_laplacian((im_h_y).astype(np.uint8))
    
    #percept_loss_input = percept_loss.forward(ToTensor()(im_gt),ToTensor()(im_in))
    #percept_loss_bicubic = percept_loss.forward(ToTensor()(im_gt),ToTensor()(im_b))
    #percept_loss_predict = percept_loss.forward(ToTensor()(im_gt),ToTensor()(im_h))
    
    # Colorize the grey-level image and convert into RGB mode

    im_gt = Image.fromarray(im_gt_ycbcr, "YCbCr").convert("RGB")
    im_b = Image.fromarray(im_b_ycbcr, "YCbCr").convert("RGB")
    
    if display:
    
        print('psnr for bicubic is {}dB'.format(psnr_bicubic))
        print('psnr for input is {}dB'.format(psnr_input))
        
        print('psnr for Model is {}dB'.format(psnr_predicted))
        print("PSNR improvement is {}dB".format(psnr_predicted - psnr_input))

        print("Sharpness Measurement GroundTruth:",blur_measure_gt)
        print("Sharpness Measurement Bicubic:",blur_measure_bicubic)
        print("Sharpness Measurement Input:",blur_measure_input)
        print("Sharpness Measurement Model:",blur_measure_vdsr)
        
        #print('perception loss for bicubic is {}'.format(percept_loss_bicubic))
        #print('perception loss for input is {}'.format(percept_loss_input))
        
        #print('perception loss for Model is {}'.format(percept_loss_predict))

        # Result visualization
        fig = plt.figure(figsize=(18, 16), dpi= 80)
        ax = plt.subplot(151)
        ax.imshow(im_gt)
        ax.set_title("GT")

        ax = plt.subplot(152)
        ax.imshow(im_b)
        ax.set_title("Bicubic")

        ax = plt.subplot(153)
        ax.imshow(im_in)
        ax.set_title("Input")

        ax = plt.subplot(154)
        ax.imshow(im_h)
        ax.set_title("Output(Model)")
        
        
        ax = plt.subplot(155)
        ax.imshow(np.clip(im_h-im_in +128,0,255))
        ax.set_title("Model-Input")
        plt.show()
    
    return im_h, psnr_bicubic, psnr_predicted

# %%
#model = torch.load("/media/SSD/superres/checkpoint/VDNEW2_epoch_15.pth")["model"]

# %%
# Load the groundtruth image and the low-resolution image (downscaled with a factor of 4)
im_gt = Image.open("/media/SSD/superres/pytorch-vdsr/Set5/butterfly_GT.bmp").convert("RGB")
im_b = Image.open("/media/SSD/superres/pytorch-vdsr/Set5/butterfly_GT_scale_4.bmp").convert("RGB")
im_b2 = CropRescale(crop_size = 256, factor_range=(5,5))(im_gt)

# %%
display_PSNR(im_gt, im_b, im_b2, model, channels=1);

# %%
# Make this load still photos too, and have them added with frame = 0
def test_results(test_dir,scale, channels=1, display = False):
    instances = []
    psnr_bicubic_sum = 0
    psnr_model_sum = 0
    ct = 0
    
    for filename in listdir(test_dir):
        filepath = os.path.join(test_dir,filename)
        #print(filepath)
                
        if is_image_file(filepath):
            im_gt = Image.open(filepath).convert("RGB")
            #print(im_gt.size)
            
            (height, width) = im_gt.size
            im_b = im_gt.resize((int(height/scale), int(width/scale)), resample = Image.BICUBIC)
            im_b = im_b.resize((height,width), resample = Image.BICUBIC)
            im_b2 = Crappify(crop_size = None, kernel_size=scale*2, quality=90)(im_gt)# open image file
            im_h, psnr_bicubic, psnr_predicted = display_PSNR(im_gt, im_b, im_b2, model, channels=channels, display = display)
            psnr_bicubic_sum = psnr_bicubic_sum + psnr_bicubic
            psnr_model_sum = psnr_model_sum + psnr_predicted
            ct = ct +1
            #item = {"Filepath":filepath, "Type":"image"}
            #instances.append(item)
        
    psnr_bicubic_avg = psnr_bicubic_sum / ct
    psnr_model_avg = psnr_model_sum / ct
        
    print("Bicubic average PSNR =",psnr_bicubic_avg)
    print("Model average PSNR =",psnr_model_avg)
    return

# %%
test_results("/media/SSD/superres/video_data/test_data/Set5", 4, channels = 1,display = True)

# %% [markdown]
# # convert sample videos

# %%
result_path

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-16.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=1.6,display=False,bitrate= "4000k")

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-10.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=False,bitrate= "4000k")

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-20.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=2.0,display=False,bitrate= "4000k")

# %%
infile = "/media/SSD/superres/muffins30sec.mp4"
outfile = result_path/"muffins30sec-30.mp4"
superres_mp4(infile, outfile, model,channels=1, factor=3.0,display=False,bitrate= "4000k")

# %%
dualfile= str(result_path/"muffins30sec-30dual.mp4")
infile = str(infile)
outfile = str(outfile)

# %%
# double scale for video x3 2 min
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -t 120 -filter_complex "[0:v] scale=iw*2:ih*2, pad=2*iw:ih [left]; [1:v] scale=iw/1.5:ih/1.5 [right]; [left][right] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
# original scale , for video x3
#!ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v] scale=iw*1:ih*1, pad=2*iw:ih [left]; [1:v] scale=iw/3:ih/3 [right]; [left][right] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
infile = "/media/SSD/superres/super8/super8_best_from_mp2.mp4"
outfile = result_path/"super8.mp4"
error_file = "/media/SSD/superres/error.txt"
superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=False,bitrate= "4000k",errorfile = error_file)

# %%
dualfile = str(result_path/"super8dual.mp4")
infile = str(infile)
outfile = str(outfile)

# %%
# original scale , for film x1, removed un needed scaling
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v]  pad=2*iw:ih [left];  [left][1:v] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
# compare this model to the last one
infile = "/media/SSD/superres/Results/Superresolution train vdsr with hres perception loss multifuz/super8hresperfuzmodel2.mp4"
outfile = str(result_path/"super8.mp4")
dualfile= str(result_path/"super8-tolast-dual.mp4")

# %%
# original scale , for film x1, removed un needed scaling
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v]  pad=2*iw:ih [left];  [left][1:v] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}

# %%
infile = "/media/SSD/superres/super8/Old 8mm Reels_1.mp4"
outfile = str(result_path/"super8long.mp4")
error_file = "/media/SSD/superres/error.txt"
superres_mp4(infile, outfile, model,channels=1, factor=1.0,display=False,bitrate= "4000k",errorfile = error_file)

# %%
# Above will error out since channels is set to 3....

# %%
dualfile= str(result_path/"super8longdual.mp4")
infile = str(infile)
outfile = str(outfile)

# %%
# original scale , for film x1, removed un needed scaling
# !ffmpeg -i {'"'+infile+'"'} -i {'"'+outfile+'"'} -filter_complex "[0:v]  pad=2*iw:ih [left];  [left][1:v] overlay=main_w/2:0" -b:v 4000k {'"'+dualfile+'"'}
